# %% [markdown]
# # 项目：指导四轴飞行器学会飞行
#
# 设计一个能够使四轴飞行器飞行的智能体，然后使用你选择的强化学习算法训练它！
#
# 请尝试运用你在这一单元中学到的知识，看看哪个方法效果最好，当然你也可以自己想出创新型方法并测试它们。
# ## 说明
#
# 请查看目录下的文件，以更好地了解项目结构。
#
# - `task.py`：在本文件中定义你的任务（环境）。
# - `agents/`：本文件夹中包含强化学习智能体。
#     - `policy_search.py`：我们为你提供了一个智能体模板。
#     - `agent.py`：在本文件中开发你的智能体。
# - `physics_sim.py`：本文件中包含四轴飞行器模拟器。**请勿修改本文件**。
#
# 在本项目中，你需要在 `task.py` 中定义你的任务。尽管我们为你提供了一个任务示例，来帮助你开始项目，但你也可以随意更改这个文件。在这个 notebook 中，你还将学习更多有关修改这个文件的知识。
#
# 你还需要在 `agent.py` 中设计一个强化学习智能体，来完成你选择的任务。
#
# 我们也鼓励你创建其他文件，来帮助你整理代码。比如，你也许可以通过定义一个 `model.py` 文件来定义其他你需要的神经网络结构。
#
# ## 控制四轴飞行器
#
# 在下方的代码中，我们提供了一个智能体示例，来示范如何使用模拟器来控制四轴飞行器。这个智能体比你在 notebook 中需要测试的智能体（在 `agents/policy_search.py` 中）更加简单！
#
# 这个智能体通过设置飞行器四个轴上的转速来控制飞行器。`Basic_Agent` 类中提供的智能体将会随机为四个轴指定动作。这四个速度将通过 `act` 方法以四个浮点数列表的形式返回。
#
# 在本项目中，你将在 `agents/agent.py` 中实现的智能体会以更加智能的方法进行指定的动作。

# %% [markdown]
# ### plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_run(results, standalone=True):
    if standalone:
        plt.subplots(figsize=(15, 15))
    
    #查看四轴飞行器的位置变化
    plt.subplot(3, 3, 1)
    plt.title('Position')
    plt.plot(results['time'], results['x'], label='x')
    plt.plot(results['time'], results['y'], label='y')
    plt.plot(results['time'], results['z'], label='z')
    plt.xlabel('time, seconds')
    plt.ylabel('Position')
    plt.grid(True)
    if standalone:
        plt.legend()

    #四轴飞行器的速度
    plt.subplot(3, 3, 2)
    plt.title('Velocity')
    plt.plot(results['time'], results['x_velocity'], label='x_hat')
    plt.plot(results['time'], results['y_velocity'], label='y_hat')
    plt.plot(results['time'], results['z_velocity'], label='z_hat')
    plt.xlabel('time, seconds')
    plt.ylabel('Velocity')
    plt.grid(True)
    if standalone:
        plt.legend()
    
    #绘制欧拉角 (Euler angles)（四轴飞行器围绕 x，y 和 z 轴的旋转）的图表
    plt.subplot(3, 3, 3)
    plt.title('Orientation')
    plt.plot(results['time'], results['phi'], label='phi')
    plt.plot(results['time'], results['theta'], label='theta')
    plt.plot(results['time'], results['psi'], label='psi')
    plt.xlabel('time, seconds')
    plt.grid(True)
    if standalone:
        plt.legend()
    
    #绘制每个欧拉角的速度（每秒的弧度）图
    plt.subplot(3, 3, 4)
    plt.title('Angular Velocity')
    plt.plot(results['time'], results['phi_velocity'], label='phi')
    plt.plot(results['time'], results['theta_velocity'], label='theta')
    plt.plot(results['time'], results['psi_velocity'], label='psi')
    plt.xlabel('time, seconds')
    plt.grid(True)
    if standalone:
        plt.legend()

    #最后，你可以使用下方代码来输出智能体选择的动作。
    plt.subplot(3, 3, 5)
    plt.title('Rotor Speed')
    plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1')
    plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2')
    plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3')
    plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4')
    plt.xlabel('time, seconds')
    plt.ylabel('Rotor Speed, revolutions / second')
    plt.grid(True)
    if standalone:
        plt.legend()

    if standalone:
        plt.tight_layout()
        plt.show()

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D


def plot_point3d(ax, x, y, z, **kwargs):
    ax.scatter([x], [y], [z], **kwargs)
    ax.text(x, y, z, "({:.1f}, {:.1f}, {:.1f})".format(x, y, z))


def show_flight_path(results, target=None):
    results = np.array(results)
    
    fig = plt.figure(figsize=(10,10))
    ax = fig.gca(projection='3d')
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')

    ax.plot3D(results[:, 0], results[:, 1], results[:, 2], 'gray')
    
    if target is not None:
        plot_point3d(ax, *target[0:3], c='y', marker='x', s=100, label='target')
        
    plot_point3d(ax, *results[0, 0:3], c='g', marker='o', s=50, label='start')
    plot_point3d(ax, *results[-1, 0:3], c='r', marker='o', s=50, label='end')
    
    ax.legend()

# %% [markdown]
# ### random Agent

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# 运行下方代码，让智能体指定动作来控制四轴飞行器。
#
# 请随意更改我们提供的 `runtime`，`init_pose`，`init_velocities` 和 `init_angle_velocities` 值来更改四轴飞行器的初始条件。
#
# 下方的 `labels` 列表为模拟数据的注释。所有的信息都储存在 `data.txt` 文档中，并保存在 `results` 目录下。

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %%
plot_run(results)

# %%
path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=None)

# %% [markdown]
# 在指定任务之前，你需要在模拟器中衍生环境状态。运行下方代码来在模拟结束时输出以下变量值：
#
# - `task.sim.pose`：四周飞行器在 ($x,y,z$) 坐标系中的位置和欧拉角。
# - `task.sim.v`：四轴飞行器在 ($x,y,z$) 坐标系中的速度。
# - `task.sim.angular_v`：三个欧拉角的弧度/每秒。

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [22.67279745  1.96369011 24.24919673  0.19931884  5.45477429  0.        ]
# [14.15315773  1.86823853  0.06854711]
# [ 0.10057598 -0.1558947   0.        ]

# %% [markdown]
# 在 `task.py` 中的任务示例中，我们使用了四轴飞行器六个维度的动作来构建每个时间步的环境状态。然而，你也可以按照自己的意愿更改任务，你可以添加速度信息来扩大状态向量，也可以使用任何动作、速度和角速度的组合，并构造适用于你的任务的环境状态。
#
# ## 任务
#
# 在 `task.py` 中，我们为你提供了一个任务示例。请在新窗口中打开这个文件。
#
# 使用 `__init__()` 方法来初始化指定本任务所需的几个变量。
#
# - 模拟器作为 `PhysicsSim` 类（来自 `physics_sim.py` 文件）的示例进行初始化。
# - 受到 DDPG 论文中研究方法的启发，我们使用了重复调用动作的方法。对于智能体的每一个时间步，我们将利用 `action_repeats` 时间步来进行模拟。如果你并不熟悉这种方法，可以阅读 [DDPG 论文](https://arxiv.org/abs/1509.02971)的结论部分。
# - 我们设置了状态向量中每个分量的数值。在任务示例中，我们只设置了六个维度的动作信息。为了设定向量大小（`state_size`），我们必须考虑重复的动作。
# - 任务环境通常是一个四维动作空间，每个轴有一个输入（`action_size=4`）。你可以设置每个输入的最小值（`action_low`）和最大值（`action_high`）。
# - 我们在文件中提供的任务示例将使智能体达到目标位置。我们将目标位置设置为一个变量。
#
# `reset()` 方法将重置模拟器。每当阶段结束时，智能体都将调用此方法。你可以查看下方代码中的例子。
#
# `step()` 方法是最重要的一个方法。它将接收智能体选择的动作 `rotor_speeds`，并准备好下一个状态，同时返回给智能体。接着，你将通过 `get_reward()` 计算奖励值。当超过规定时间，或是四轴飞行器到达模拟器边缘时，这一阶段将视作结束。
#
# 接下来，你将学习如何测试这个任务中智能体的性能。
#
# ## 智能体
#
# `agents/policy_search.py` 文件中提供的智能体示例使用了非常简单的线性策略，将动作向量视作状态向量和矩阵权重的点积直接进行计算。接着，它通过添加一些高斯噪声来随机干扰参数，以产生不同的策略。根据每个阶段获得的平均奖励值（`score`），它将记录迄今为止发现的最佳参数集以及分数的变化状态，并据此调整比例因子来扩大或减少噪音。
#
# 请运行下方代码来查看任务示例中智能体的性能。

# %%
import sys
import pandas as p

# %%
from agents.policy_search import PolicySearch_Agent
from task import Task

labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

num_episodes = 1
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        if i_episode == num_episodes:
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode =    1, score =  -0.786 (best =  -0.786), noise_scale = 0.05

# %%
plot_run(results)

path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=target_pos)

# %% [markdown]
# 这个智能体的性能想必十分糟糕！现在轮到你出场了！
#
# ## 定义任务，设计并训练你的智能体！
#
# 修改 `task.py` 文件来指定你所选择的任务。如果你不确定选择什么任务，你可以教你的四轴飞行器起飞、盘旋、着陆或是达到指定位置。
#
#
# 在指定任务后，使用 `agents/policy_search.py` 中的智能体示例作为模板，来在 `agents/agent.py` 中定义你自己的智能体。你可以随意从智能体示例中借用你需要的元素，包括如何模块化你的代码（使用 `act()`，`learn()` 和 `reset_episode_vars()` 等辅助方法）。
#
# 请注意，你指定的第一个智能体和任务**极有可能**无法顺利进行学习。你将需要改进不同的超参数和奖励函数，直到你能够获得不错的结果。
#
# 在开发智能体的时候，你还需要关注它的性能。参考下方代码，建立一个机制来存储每个阶段的总奖励值。如果阶段奖励值在逐渐上升，说明你的智能体正在学习。

# %%
## TODO: Train your agent here.
from agents.ddpg_agent import DDPG_Agent
from quadcopter_task import Quadcopter_Task
import sys
import pandas as p
import numpy as np
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}
rewards = {"episode":[],"reward":[]}
num_episodes = 600
target_pos = np.array([0., 0., 100.])
init_pos = np.array([0., 0., 100., 0., 0., 0.])
task = Quadcopter_Task(target_pos=target_pos, init_pose=init_pos)
agent = DDPG_Agent(task) 
worst_score = 1000000
best_score = -1000000.
for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    score = 0
    while True:
        action = agent.act(state) 
        #print("action:{}".format(action))
        next_state, reward, done = task.step(action)
        if i_episode == num_episodes:
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
        #print("reward:{},done:{}".format(reward,done))
        
        score += reward
        best_score = max(best_score , score)
        worst_score = min(worst_score , score)
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
            print("\rEpisode ={:4d},pose ={:7.3f}, velocity[z]={:7.3f}, score ={:7.3f}(best ={:7.3f},worst ={:7.3f})".format(
               i_episode, task.sim.pose[2],task.sim.v[2],score, best_score, worst_score))
            break
    rewards['episode'].append(i_episode)
    rewards['reward'].append(score)
    sys.stdout.flush()
# Out:
# sim.init_pos:[  0.   0. 100.   0.   0.   0.]
# Episode =   1,pose = 32.079, velocity[z]=-34.886, score =575.153(best =575.153,worst =  6.854)
# Episode =   2,pose =  0.000, velocity[z]=-62.859, score =519.865(best =575.153,worst =  6.854)
# Episode =   3,pose =  0.000, velocity[z]=-41.708, score =549.255(best =575.153,worst =  6.854)
# Episode =   4,pose =  0.000, velocity[z]=-37.908, score =570.334(best =575.153,worst =  6.854)
# Episode =   5,pose = 16.799, velocity[z]=-20.690, score =578.636(best =578.636,worst =  6.854)
# Episode =   6,pose =  0.000, velocity[z]=-47.924, score =558.004(best =578.636,worst =  6.854)
# Episode =   7,pose = 20.870, velocity[z]=-29.917, score =576.939(best =578.636,worst =  6.854)
# Episode =   8,pose =  0.000, velocity[z]=-33.256, score =573.653(best =578.636,worst =  6.854)
# Episode =   9,pose =  0.000, velocity[z]=-48.869, score =558.427(best =578.636,worst =  6.854)
# Episode =  10,pose =  1.395, velocity[z]=-34.407, score =576.208(best =578.636,worst =  6.854)
# Episode =  11,pose =  0.000, velocity[z]=-40.171, score =553.875(best =578.636,worst =  6.854)
# Episode =  12,pose =  0.000, velocity[z]=-38.211, score =583.325(best =583.325,worst =  6.854)
# Episode =  13,pose = 20.476, velocity[z]= 14.958, score =572.097(best =583.325,worst =  6.854)
# Episode =  14,pose =  0.000, velocity[z]=-43.598, score =570.806(best =583.325,worst =  6.854)
# Episode =  15,pose = 25.233, velocity[z]= 46.805, score =557.160(best =583.325,worst =  6.854)
# Episode =  16,pose =  0.649, velocity[z]=-32.454, score =579.321(best =583.325,worst =  6.854)
# Episode =  17,pose =  0.000, velocity[z]=-37.337, score =561.303(best =583.325,worst =  6.854)
# Episode =  18,pose =  0.000, velocity[z]=-34.208, score =566.502(best =583.325,worst =  6.854)
# Episode =  19,pose =  5.154, velocity[z]=-31.961, score =575.306(best =583.325,worst =  6.854)
# Episode =  20,pose = 24.170, velocity[z]=-19.012, score =578.025(best =583.325,worst =  6.854)
# Episode =  21,pose = 25.033, velocity[z]=-11.527, score =574.825(best =583.325,worst =  6.854)
# Episode =  22,pose =  5.594, velocity[z]=-34.155, score =578.435(best =583.325,worst =  6.854)
# Episode =  23,pose =  0.000, velocity[z]=-37.499, score =567.235(best =583.325,worst =  6.854)
# Episode =  24,pose = 14.306, velocity[z]=-34.818, score =575.551(best =583.325,worst =  6.854)
# Episode =  25,pose =  0.000, velocity[z]=-48.134, score =558.673(best =583.325,worst =  6.854)
# Episode =  26,pose =  0.000, velocity[z]=-39.081, score =578.053(best =583.325,worst =  6.854)
# Episode =  27,pose =  0.000, velocity[z]=-52.501, score =569.365(best =583.325,worst =  6.854)
# Episode =  28,pose =  0.000, velocity[z]=-47.332, score =559.376(best =583.325,worst =  6.854)
# Episode =  29,pose =  0.000, velocity[z]=-32.375, score =563.449(best =583.325,worst =  6.854)
# Episode =  30,pose =  0.000, velocity[z]=-46.391, score =553.679(best =583.325,worst =  6.854)
# Episode =  31,pose =  0.000, velocity[z]=-43.023, score =564.603(best =583.325,worst =  6.854)
# Episode =  32,pose =  1.916, velocity[z]=-28.047, score =580.364(best =583.325,worst =  6.854)
# Episode =  33,pose =  8.945, velocity[z]=-26.553, score =578.535(best =583.325,worst =  6.854)
# Episode =  34,pose =  0.000, velocity[z]=-39.654, score =557.020(best =583.325,worst =  6.854)
# Episode =  35,pose =  0.444, velocity[z]=-31.333, score =579.769(best =583.325,worst =  6.854)
# Episode =  36,pose =  0.000, velocity[z]=-45.099, score =543.380(best =583.325,worst =  6.854)
# Episode =  37,pose =  7.396, velocity[z]=-33.562, score =576.879(best =583.325,worst =  6.854)
# Episode =  38,pose =  0.000, velocity[z]=-39.749, score =560.269(best =583.325,worst =  6.854)
# Episode =  39,pose =  0.000, velocity[z]=-53.445, score =559.023(best =583.325,worst =  6.854)
# Episode =  40,pose =  0.000, velocity[z]=-37.132, score =557.464(best =583.325,worst =  6.854)
# Episode =  41,pose = 22.001, velocity[z]=-18.459, score =578.169(best =583.325,worst =  6.854)
# Episode =  42,pose =  6.884, velocity[z]=-26.157, score =578.916(best =583.325,worst =  6.854)
# Episode =  43,pose =  4.477, velocity[z]=-52.063, score =575.316(best =583.325,worst =  6.854)
# Episode =  44,pose = 10.174, velocity[z]=  1.721, score =575.951(best =583.325,worst =  6.854)
# Episode =  45,pose =  0.000, velocity[z]=-53.142, score =525.995(best =583.325,worst =  6.854)
# Episode =  46,pose =  1.006, velocity[z]=-31.775, score =579.410(best =583.325,worst =  6.854)
# Episode =  47,pose = 15.580, velocity[z]=-35.122, score =576.166(best =583.325,worst =  6.854)
# Episode =  48,pose =  0.000, velocity[z]=-39.210, score =561.023(best =583.325,worst =  6.854)
# Episode =  49,pose =  7.985, velocity[z]=-46.254, score =573.175(best =583.325,worst =  6.854)
# Episode =  50,pose =  3.289, velocity[z]=-29.564, score =579.365(best =583.325,worst =  6.854)
# Episode =  51,pose =  0.000, velocity[z]=-35.840, score =581.226(best =583.325,worst =  6.854)
# Episode =  52,pose =  0.000, velocity[z]=-45.006, score =538.748(best =583.325,worst =  6.854)
# Episode =  53,pose =  0.000, velocity[z]=-46.776, score =548.565(best =583.325,worst =  6.854)
# Episode =  54,pose =  4.308, velocity[z]=-51.415, score =576.246(best =583.325,worst =  6.854)
# Episode =  55,pose = 15.554, velocity[z]=-21.006, score =578.765(best =583.325,worst =  6.854)
# Episode =  56,pose =  8.604, velocity[z]=-26.549, score =579.979(best =583.325,worst =  6.854)
# Episode =  57,pose =  0.000, velocity[z]=-37.493, score =561.059(best =583.325,worst =  6.854)
# Episode =  58,pose =  7.001, velocity[z]=-25.509, score =579.475(best =583.325,worst =  6.854)
# Episode =  59,pose = 16.873, velocity[z]=-30.202, score =577.451(best =583.325,worst =  6.854)
# Episode =  60,pose = 26.209, velocity[z]= 14.602, score =536.516(best =583.325,worst =  6.854)
# Episode =  61,pose =  0.000, velocity[z]=-48.000, score =542.181(best =583.325,worst =  6.854)
# Episode =  62,pose =  6.207, velocity[z]=-40.507, score =572.486(best =583.325,worst =  6.854)
# Episode =  63,pose = 94.628, velocity[z]= -1.078, score =585.735(best =585.735,worst =  6.854)
# Episode =  64,pose = 93.885, velocity[z]= -1.548, score =585.645(best =585.735,worst =  6.854)
# Episode =  65,pose = 89.377, velocity[z]= -3.850, score =584.595(best =585.735,worst =  6.854)
# Episode =  66,pose = 95.342, velocity[z]= -1.119, score =585.992(best =585.992,worst =  6.854)
# Episode =  67,pose = 94.956, velocity[z]= -1.455, score =585.975(best =585.992,worst =  6.854)
# Episode =  68,pose =101.322, velocity[z]=  1.087, score =587.426(best =587.426,worst =  6.854)
# Episode =  69,pose = 90.284, velocity[z]= -2.717, score =584.757(best =587.426,worst =  6.854)
# Episode =  70,pose = 97.816, velocity[z]= -0.182, score =586.646(best =587.426,worst =  6.854)
# Episode =  71,pose = 92.638, velocity[z]= -2.078, score =585.343(best =587.426,worst =  6.854)
# Episode =  72,pose = 90.180, velocity[z]= -3.312, score =584.867(best =587.426,worst =  6.854)
# Episode =  73,pose = 95.004, velocity[z]= -1.473, score =585.960(best =587.426,worst =  6.854)
# Episode =  74,pose = 96.919, velocity[z]= -0.237, score =586.329(best =587.426,worst =  6.854)
# Episode =  75,pose = 92.194, velocity[z]= -2.054, score =585.231(best =587.426,worst =  6.854)
# Episode =  76,pose =101.612, velocity[z]=  1.168, score =587.445(best =587.445,worst =  6.854)
# Episode =  77,pose = 98.386, velocity[z]= -0.181, score =586.933(best =587.445,worst =  6.854)
# Episode =  78,pose = 88.839, velocity[z]= -3.695, score =584.531(best =587.445,worst =  6.854)
# Episode =  79,pose = 89.927, velocity[z]= -2.895, score =584.685(best =587.445,worst =  6.854)
# Episode =  80,pose = 94.334, velocity[z]= -1.986, score =585.766(best =587.445,worst =  6.854)
# Episode =  81,pose =  0.000, velocity[z]=-141.629, score =389.915(best =587.445,worst =  6.854)
# Episode =  82,pose =124.708, velocity[z]=1172.532, score =576.718(best =587.445,worst =  6.854)
# Episode =  83,pose =  0.000, velocity[z]=-72.020, score =376.492(best =587.445,worst =  6.854)
# Episode =  84,pose = 21.537, velocity[z]=-45.003, score =583.242(best =587.445,worst =  6.854)
# Episode =  85,pose =  6.571, velocity[z]=-406.762, score =430.259(best =587.445,worst =  6.854)
# Episode =  86,pose =  0.000, velocity[z]=-54.004, score =491.685(best =587.445,worst =  6.854)
# Episode =  87,pose =  0.000, velocity[z]=-81.324, score =496.128(best =587.445,worst =  6.854)
# Episode =  88,pose =  0.000, velocity[z]=-67.146, score =518.218(best =587.445,worst =  6.854)
# Episode =  89,pose =  0.000, velocity[z]=-47.650, score =569.298(best =587.445,worst =  6.854)
# Episode =  90,pose =  0.000, velocity[z]=-60.955, score =327.094(best =587.445,worst =  6.854)
# Episode =  91,pose =  0.000, velocity[z]=-48.789, score =530.522(best =587.445,worst =  6.854)
# Episode =  92,pose = 48.365, velocity[z]=-40.520, score =589.427(best =589.427,worst =  6.854)
# Episode =  93,pose = 64.364, velocity[z]=-34.312, score =579.122(best =589.427,worst =  6.854)
# Episode =  94,pose =  0.000, velocity[z]=-58.968, score =485.030(best =589.427,worst =  6.854)
# Episode =  95,pose = 24.152, velocity[z]=-84.372, score =583.567(best =589.427,worst =  6.854)
# Episode =  96,pose =  0.000, velocity[z]=-57.978, score =548.628(best =589.427,worst =  6.854)
# Episode =  97,pose =  0.000, velocity[z]=-41.450, score =586.223(best =589.427,worst =  6.854)
# Episode =  98,pose =  3.515, velocity[z]=-26.787, score =578.904(best =589.427,worst =  6.854)
# Episode =  99,pose = 29.514, velocity[z]=-25.824, score =583.950(best =589.427,worst =  6.854)
# Episode = 100,pose =  0.000, velocity[z]=-44.403, score =558.844(best =589.427,worst =  6.854)
# Episode = 101,pose = 24.771, velocity[z]=-51.434, score =583.301(best =589.427,worst =  6.854)
# Episode = 102,pose = 24.238, velocity[z]=-27.612, score =582.029(best =589.427,worst =  6.854)
# Episode = 103,pose = 18.970, velocity[z]=-21.996, score =580.744(best =589.427,worst =  6.854)
# Episode = 104,pose =  0.000, velocity[z]=-48.000, score =553.736(best =589.427,worst =  6.854)
# Episode = 105,pose =  0.000, velocity[z]=-66.597, score =530.965(best =589.427,worst =  6.854)
# Episode = 106,pose =  0.000, velocity[z]=-55.701, score =550.964(best =589.427,worst =  6.854)
# Episode = 107,pose =  0.000, velocity[z]=-181.256, score =538.446(best =589.427,worst =  6.854)
# Episode = 108,pose =233.085, velocity[z]= 36.409, score =570.598(best =589.427,worst =  6.854)
# Episode = 109,pose =254.763, velocity[z]= 66.244, score =568.830(best =589.427,worst =  6.854)
# Episode = 110,pose =212.619, velocity[z]= 10.333, score =568.761(best =589.427,worst =  6.854)
# Episode = 111,pose =215.853, velocity[z]= 12.084, score =569.933(best =589.427,worst =  6.854)
# Episode = 112,pose =300.000, velocity[z]=258.762, score =539.802(best =589.427,worst =  6.854)
# Episode = 113,pose =227.528, velocity[z]= 27.634, score =571.433(best =589.427,worst =  6.854)
# Episode = 114,pose =227.634, velocity[z]= 26.721, score =570.952(best =589.427,worst =  6.854)
# Episode = 115,pose =  0.000, velocity[z]=-45.915, score =435.655(best =589.427,worst =  6.854)
# Episode = 116,pose =  0.000, velocity[z]=-39.656, score =485.562(best =589.427,worst =  6.854)
# Episode = 117,pose =227.299, velocity[z]= 27.019, score =571.835(best =589.427,worst =  6.854)
# Episode = 118,pose =232.930, velocity[z]= 28.711, score =571.192(best =589.427,worst =  6.854)
# Episode = 119,pose =216.630, velocity[z]= 14.750, score =569.969(best =589.427,worst =  6.854)
# Episode = 120,pose =225.469, velocity[z]= 24.733, score =570.834(best =589.427,worst =  6.854)
# Episode = 121,pose =229.578, velocity[z]= 28.156, score =570.878(best =589.427,worst =  6.854)
# Episode = 122,pose =216.850, velocity[z]= 16.608, score =568.899(best =589.427,worst =  6.854)
# Episode = 123,pose =211.616, velocity[z]=  7.476, score =570.037(best =589.427,worst =  6.854)
# Episode = 124,pose =226.573, velocity[z]= 27.739, score =570.631(best =589.427,worst =  6.854)
# Episode = 125,pose =295.391, velocity[z]=199.655, score =564.849(best =589.427,worst =  6.854)
# Episode = 126,pose =102.434, velocity[z]=-22.652, score =584.764(best =589.427,worst =  6.854)
# Episode = 127,pose =125.411, velocity[z]= -3.922, score =583.675(best =589.427,worst =  6.854)
# Episode = 128,pose =  0.000, velocity[z]=-39.279, score =563.882(best =589.427,worst =  6.854)
# Episode = 129,pose =  0.000, velocity[z]=-31.206, score =590.127(best =590.127,worst =  6.854)
# Episode = 130,pose =  0.000, velocity[z]=-71.236, score =563.950(best =590.127,worst =  6.854)
# Episode = 131,pose = 33.389, velocity[z]=-16.585, score =569.534(best =590.127,worst =  6.854)
# Episode = 132,pose =  3.064, velocity[z]=-42.365, score =578.091(best =590.127,worst =  6.854)
# Episode = 133,pose =  0.000, velocity[z]=-42.212, score =555.428(best =590.127,worst =  6.854)
# Episode = 134,pose = 29.448, velocity[z]=-32.556, score =575.740(best =590.127,worst =  6.854)
# Episode = 135,pose =  3.332, velocity[z]=-44.659, score =574.056(best =590.127,worst =  6.854)
# Episode = 136,pose =  0.000, velocity[z]=-49.254, score =546.935(best =590.127,worst =  6.854)
# Episode = 137,pose =  0.000, velocity[z]=-45.987, score =586.507(best =590.127,worst =  6.854)
# Episode = 138,pose = 26.708, velocity[z]=-46.663, score =579.773(best =590.127,worst =  6.854)
# Episode = 139,pose = 98.389, velocity[z]=-14.215, score =585.334(best =590.127,worst =  6.854)
# Episode = 140,pose = 94.108, velocity[z]=-21.711, score =585.962(best =590.127,worst =  6.854)
# Episode = 141,pose =  0.000, velocity[z]=-40.611, score =543.031(best =590.127,worst =  6.854)
# Episode = 142,pose =  0.000, velocity[z]=-40.455, score =543.029(best =590.127,worst =  6.854)
# Episode = 143,pose =  0.000, velocity[z]=-40.441, score =543.044(best =590.127,worst =  6.854)
# Episode = 144,pose =  0.000, velocity[z]=-40.443, score =543.054(best =590.127,worst =  6.854)
# Episode = 145,pose =  0.000, velocity[z]=-40.443, score =543.047(best =590.127,worst =  6.854)
# Episode = 146,pose =  0.000, velocity[z]=-40.451, score =543.036(best =590.127,worst =  6.854)
# Episode = 147,pose =  0.000, velocity[z]=-40.441, score =543.043(best =590.127,worst =  6.854)
# Episode = 148,pose =  0.000, velocity[z]=-40.446, score =543.047(best =590.127,worst =  6.854)
# Episode = 149,pose =  0.000, velocity[z]=-40.439, score =543.045(best =590.127,worst =  6.854)
# Episode = 150,pose =  0.000, velocity[z]=-40.446, score =543.037(best =590.127,worst =  6.854)
# Episode = 151,pose =  0.000, velocity[z]=-40.442, score =543.033(best =590.127,worst =  6.854)
# Episode = 152,pose =  0.000, velocity[z]=-40.446, score =543.031(best =590.127,worst =  6.854)
# Episode = 153,pose =  0.000, velocity[z]=-40.436, score =543.055(best =590.127,worst =  6.854)
# Episode = 154,pose =  0.000, velocity[z]=-40.447, score =543.022(best =590.127,worst =  6.854)
# Episode = 155,pose =  0.000, velocity[z]=-40.449, score =543.036(best =590.127,worst =  6.854)
# Episode = 156,pose =  0.000, velocity[z]=-40.432, score =543.054(best =590.127,worst =  6.854)
# Episode = 157,pose =  0.000, velocity[z]=-40.453, score =543.022(best =590.127,worst =  6.854)
# Episode = 158,pose =  0.000, velocity[z]=-40.447, score =543.038(best =590.127,worst =  6.854)
# Episode = 159,pose =  0.000, velocity[z]=-40.439, score =543.038(best =590.127,worst =  6.854)
# Episode = 160,pose =  0.000, velocity[z]=-40.441, score =543.045(best =590.127,worst =  6.854)
# Episode = 161,pose =  0.000, velocity[z]=-40.450, score =543.052(best =590.127,worst =  6.854)
# Episode = 162,pose =  0.000, velocity[z]=-40.455, score =543.026(best =590.127,worst =  6.854)
# Episode = 163,pose =  0.000, velocity[z]=-40.443, score =543.037(best =590.127,worst =  6.854)
# Episode = 164,pose =  0.000, velocity[z]=-40.438, score =543.048(best =590.127,worst =  6.854)
# Episode = 165,pose =  0.000, velocity[z]=-40.442, score =543.062(best =590.127,worst =  6.854)
# Episode = 166,pose =  0.000, velocity[z]=-40.437, score =543.054(best =590.127,worst =  6.854)
# Episode = 167,pose =  0.000, velocity[z]=-40.450, score =543.036(best =590.127,worst =  6.854)
# Episode = 168,pose =  0.000, velocity[z]=-40.436, score =543.043(best =590.127,worst =  6.854)
# Episode = 169,pose =  0.000, velocity[z]=-40.437, score =543.061(best =590.127,worst =  6.854)
# Episode = 170,pose =  0.000, velocity[z]=-40.440, score =543.038(best =590.127,worst =  6.854)
# Episode = 171,pose =  0.000, velocity[z]=-40.445, score =543.039(best =590.127,worst =  6.854)
# Episode = 172,pose =  0.000, velocity[z]=-40.441, score =543.036(best =590.127,worst =  6.854)
# Episode = 173,pose =  0.000, velocity[z]=-40.439, score =543.049(best =590.127,worst =  6.854)
# Episode = 174,pose =  0.000, velocity[z]=-40.463, score =543.029(best =590.127,worst =  6.854)
# Episode = 175,pose =  0.000, velocity[z]=-40.446, score =543.051(best =590.127,worst =  6.854)
# Episode = 176,pose =  0.000, velocity[z]=-40.434, score =543.047(best =590.127,worst =  6.854)
# Episode = 177,pose =  0.000, velocity[z]=-40.443, score =543.059(best =590.127,worst =  6.854)
# Episode = 178,pose =  0.000, velocity[z]=-40.450, score =543.036(best =590.127,worst =  6.854)
# Episode = 179,pose =  0.000, velocity[z]=-40.445, score =543.034(best =590.127,worst =  6.854)
# Episode = 180,pose =  0.000, velocity[z]=-40.444, score =543.062(best =590.127,worst =  6.854)
# Episode = 181,pose =  0.000, velocity[z]=-40.450, score =543.044(best =590.127,worst =  6.854)
# Episode = 182,pose =  0.000, velocity[z]=-40.433, score =543.065(best =590.127,worst =  6.854)
# Episode = 183,pose =  0.000, velocity[z]=-40.444, score =543.046(best =590.127,worst =  6.854)
# Episode = 184,pose =  0.000, velocity[z]=-40.434, score =543.051(best =590.127,worst =  6.854)
# Episode = 185,pose =  0.000, velocity[z]=-40.437, score =543.049(best =590.127,worst =  6.854)
# Episode = 186,pose =  0.000, velocity[z]=-40.453, score =543.031(best =590.127,worst =  6.854)
# Episode = 187,pose =  0.000, velocity[z]=-40.451, score =543.064(best =590.127,worst =  6.854)
# Episode = 188,pose =  0.000, velocity[z]=-40.441, score =543.045(best =590.127,worst =  6.854)
# Episode = 189,pose =  0.000, velocity[z]=-40.443, score =543.045(best =590.127,worst =  6.854)
# Episode = 190,pose =  0.000, velocity[z]=-46.527, score =543.034(best =590.127,worst =  6.854)
# Episode = 191,pose =  0.000, velocity[z]=-40.444, score =543.041(best =590.127,worst =  6.854)
# Episode = 192,pose =  0.000, velocity[z]=-40.450, score =543.027(best =590.127,worst =  6.854)
# Episode = 193,pose =  0.000, velocity[z]=-49.549, score =553.042(best =590.127,worst =  6.854)
# Episode = 194,pose =  0.000, velocity[z]=-37.599, score =559.425(best =590.127,worst =  6.854)
# Episode = 195,pose =  0.000, velocity[z]=-44.069, score =543.046(best =590.127,worst =  6.854)
# Episode = 196,pose =  0.000, velocity[z]=-41.342, score =533.044(best =590.127,worst =  6.854)
# Episode = 197,pose =  0.000, velocity[z]=-65.503, score =530.099(best =590.127,worst =  6.854)
# Episode = 198,pose =  0.000, velocity[z]=-69.884, score =506.809(best =590.127,worst =  6.854)
# Episode = 199,pose =  0.000, velocity[z]=-48.170, score =499.470(best =590.127,worst =  6.854)
# Episode = 200,pose =  0.000, velocity[z]=-69.037, score =486.490(best =590.127,worst =  6.854)
# Episode = 201,pose =  0.000, velocity[z]=-62.471, score =490.072(best =590.127,worst =  6.854)
# Episode = 202,pose =  0.000, velocity[z]=-44.974, score =546.171(best =590.127,worst =  6.854)
# Episode = 203,pose =  0.000, velocity[z]=-42.844, score =509.223(best =590.127,worst =  6.854)
# Episode = 204,pose =  0.000, velocity[z]=-52.974, score =512.696(best =590.127,worst =  6.854)
# Episode = 205,pose =  0.000, velocity[z]=-39.333, score =505.846(best =590.127,worst =  6.854)
# Episode = 206,pose =  0.000, velocity[z]=-48.786, score =502.640(best =590.127,worst =  6.854)
# Episode = 207,pose =  0.000, velocity[z]=-61.128, score =456.675(best =590.127,worst =  6.854)
# Episode = 208,pose =  0.000, velocity[z]=-43.747, score =529.052(best =590.127,worst =  6.854)
# Episode = 209,pose =  0.000, velocity[z]=-47.012, score =504.135(best =590.127,worst =  6.854)
# Episode = 210,pose =  0.000, velocity[z]=-40.542, score =472.204(best =590.127,worst =  6.854)
# Episode = 211,pose =  0.000, velocity[z]=-94.540, score =473.636(best =590.127,worst =  6.854)
# Episode = 212,pose =  0.000, velocity[z]=-68.408, score =463.393(best =590.127,worst =  6.854)
# Episode = 213,pose =  0.000, velocity[z]=-48.583, score =490.255(best =590.127,worst =  6.854)
# Episode = 214,pose =  0.000, velocity[z]=-39.127, score =551.144(best =590.127,worst =  6.854)
# Episode = 215,pose =  0.000, velocity[z]=-48.853, score =475.767(best =590.127,worst =  6.854)
# Episode = 216,pose =  0.000, velocity[z]=-45.084, score =495.732(best =590.127,worst =  6.854)
# Episode = 217,pose =  0.000, velocity[z]=-39.553, score =512.579(best =590.127,worst =  6.854)
# Episode = 218,pose =  0.000, velocity[z]=-113.543, score =414.144(best =590.127,worst =  6.854)
# Episode = 219,pose =  0.000, velocity[z]=-38.533, score =538.431(best =590.127,worst =  6.854)
# Episode = 220,pose =  0.000, velocity[z]=-109.390, score =420.808(best =590.127,worst =  6.854)
# Episode = 221,pose =  0.000, velocity[z]=-277.589, score =387.740(best =590.127,worst =  6.854)
# Episode = 222,pose =  0.000, velocity[z]=-59.902, score =413.762(best =590.127,worst =  6.854)
# Episode = 223,pose =  0.000, velocity[z]=-383.975, score =384.451(best =590.127,worst =  6.854)
# Episode = 224,pose =  0.000, velocity[z]=-185.314, score =367.412(best =590.127,worst =  6.854)
# Episode = 225,pose =  0.000, velocity[z]=-329.479, score =381.437(best =590.127,worst =  6.854)
# Episode = 226,pose =  0.000, velocity[z]=-24.566, score =552.479(best =590.127,worst =  6.854)
# Episode = 227,pose =  0.000, velocity[z]=-45.723, score =511.234(best =590.127,worst =  6.854)
# Episode = 228,pose =  0.000, velocity[z]=-42.268, score =542.375(best =590.127,worst =  6.854)
# Episode = 229,pose =  0.000, velocity[z]=-90.152, score =493.051(best =590.127,worst =  6.854)
# Episode = 230,pose =  0.000, velocity[z]=-48.539, score =497.091(best =590.127,worst =  6.854)
# Episode = 231,pose =  0.000, velocity[z]=-51.481, score =499.348(best =590.127,worst =  6.854)
# Episode = 232,pose =  0.000, velocity[z]=-52.016, score =519.079(best =590.127,worst =  6.854)
# Episode = 233,pose =  0.000, velocity[z]=-56.311, score =502.684(best =590.127,worst =  6.854)
# Episode = 234,pose =  0.000, velocity[z]=-43.070, score =550.807(best =590.127,worst =  6.854)
# Episode = 235,pose =  0.000, velocity[z]=-41.070, score =529.045(best =590.127,worst =  6.854)
# Episode = 236,pose =  0.000, velocity[z]=-39.482, score =519.125(best =590.127,worst =  6.854)
# Episode = 237,pose =  0.000, velocity[z]=-40.446, score =550.487(best =590.127,worst =  6.854)
# Episode = 238,pose =  0.000, velocity[z]=-144.221, score =423.810(best =590.127,worst =  6.854)
# Episode = 239,pose =  0.000, velocity[z]=-68.349, score =499.754(best =590.127,worst =  6.854)
# Episode = 240,pose =  0.000, velocity[z]=-47.194, score =499.828(best =590.127,worst =  6.854)
# Episode = 241,pose =  0.000, velocity[z]=-76.205, score =460.624(best =590.127,worst =  6.854)
# Episode = 242,pose =  0.000, velocity[z]=-48.517, score =539.309(best =590.127,worst =  6.854)
# Episode = 243,pose =  0.000, velocity[z]=-27.471, score =507.142(best =590.127,worst =  6.854)
# Episode = 244,pose =  0.000, velocity[z]=-36.929, score =452.337(best =590.127,worst =  6.854)
# Episode = 245,pose =  0.000, velocity[z]=-134.571, score =453.861(best =590.127,worst =  6.854)
# Episode = 246,pose =  0.000, velocity[z]=-117.016, score =498.485(best =590.127,worst =  6.854)
# Episode = 247,pose = 12.753, velocity[z]=-28.851, score =580.868(best =590.127,worst =  6.854)
# Episode = 248,pose =  0.000, velocity[z]=-47.858, score =495.774(best =590.127,worst =  6.854)
# Episode = 249,pose =  0.000, velocity[z]=-41.979, score =484.585(best =590.127,worst =  6.854)
# Episode = 250,pose =  0.000, velocity[z]=-29.191, score =496.190(best =590.127,worst =  6.854)
# Episode = 251,pose =  0.000, velocity[z]=-43.942, score =463.057(best =590.127,worst =  6.854)
# Episode = 252,pose =  0.000, velocity[z]=-73.562, score =519.911(best =590.127,worst =  6.854)
# Episode = 253,pose =  0.000, velocity[z]=-131.519, score =478.165(best =590.127,worst =  6.854)
# Episode = 254,pose =  0.000, velocity[z]=-36.707, score =505.041(best =590.127,worst =  6.854)
# Episode = 255,pose =  0.000, velocity[z]=-39.181, score =557.665(best =590.127,worst =  6.854)
# Episode = 256,pose =  0.000, velocity[z]=-36.474, score =521.970(best =590.127,worst =  6.854)
# Episode = 257,pose =  0.000, velocity[z]=-310.950, score =403.886(best =590.127,worst =  6.854)
# Episode = 258,pose =  0.000, velocity[z]=-68.101, score =521.382(best =590.127,worst =  6.854)
# Episode = 259,pose =  0.000, velocity[z]=-90.481, score =504.892(best =590.127,worst =  6.854)
# Episode = 260,pose =  0.000, velocity[z]=-52.800, score =499.208(best =590.127,worst =  6.854)
# Episode = 261,pose =  0.000, velocity[z]=-62.876, score =466.305(best =590.127,worst =  6.854)
# Episode = 262,pose =  0.000, velocity[z]=-70.998, score =524.848(best =590.127,worst =  6.854)
# Episode = 263,pose =  0.000, velocity[z]=-142.716, score =463.942(best =590.127,worst =  6.854)
# Episode = 264,pose =  0.000, velocity[z]=-241.964, score =437.366(best =590.127,worst =  6.854)
# Episode = 265,pose =  0.000, velocity[z]=-33.903, score =537.594(best =590.127,worst =  6.854)
# Episode = 266,pose =  0.000, velocity[z]=-43.214, score =512.253(best =590.127,worst =  6.854)
# Episode = 267,pose =  0.000, velocity[z]=-49.939, score =486.180(best =590.127,worst =  6.854)
# Episode = 268,pose =  0.000, velocity[z]=-52.625, score =499.538(best =590.127,worst =  6.854)
# Episode = 269,pose =  0.000, velocity[z]=-36.350, score =545.728(best =590.127,worst =  6.854)
# Episode = 270,pose =  0.000, velocity[z]=-43.635, score =559.053(best =590.127,worst =  6.854)
# Episode = 271,pose =  0.000, velocity[z]=-63.465, score =519.495(best =590.127,worst =  6.854)
# Episode = 272,pose =  0.000, velocity[z]=-45.323, score =546.124(best =590.127,worst =  6.854)
# Episode = 273,pose =  0.000, velocity[z]=-56.681, score =503.032(best =590.127,worst =  6.854)
# Episode = 274,pose =  0.000, velocity[z]=-41.246, score =519.405(best =590.127,worst =  6.854)
# Episode = 275,pose =  0.000, velocity[z]=-45.637, score =525.362(best =590.127,worst =  6.854)
# Episode = 276,pose =  0.000, velocity[z]=-42.736, score =519.636(best =590.127,worst =  6.854)
# Episode = 277,pose =  0.000, velocity[z]=-37.077, score =568.208(best =590.127,worst =  6.854)
# Episode = 278,pose =  0.000, velocity[z]=-153.322, score =327.117(best =590.127,worst =  6.854)
# Episode = 279,pose =  0.000, velocity[z]=-78.389, score =355.874(best =590.127,worst =  6.854)
# Episode = 280,pose =  0.000, velocity[z]=-967.380, score =274.680(best =590.127,worst =  6.854)
# Episode = 281,pose =  0.000, velocity[z]=-54.177, score =492.950(best =590.127,worst =  6.854)
# Episode = 282,pose =  0.000, velocity[z]=-45.178, score =516.460(best =590.127,worst =  6.854)
# Episode = 283,pose =  0.000, velocity[z]=-64.709, score =488.562(best =590.127,worst =  6.854)
# Episode = 284,pose =  0.000, velocity[z]=-63.661, score =448.402(best =590.127,worst =  6.854)
# Episode = 285,pose =  0.000, velocity[z]=-49.022, score =532.889(best =590.127,worst =  6.854)
# Episode = 286,pose =  0.000, velocity[z]=-35.208, score =542.702(best =590.127,worst =  6.854)
# Episode = 287,pose =  0.000, velocity[z]=-741.302, score =327.296(best =590.127,worst =  6.854)
# Episode = 288,pose =  0.000, velocity[z]=-45.057, score =505.886(best =590.127,worst =  6.854)
# Episode = 289,pose =  0.000, velocity[z]=-49.676, score =559.498(best =590.127,worst =  6.854)
# Episode = 290,pose =  0.000, velocity[z]=-41.174, score =539.819(best =590.127,worst =  6.854)
# Episode = 291,pose =  0.000, velocity[z]=-40.406, score =550.230(best =590.127,worst =  6.854)
# Episode = 292,pose = 60.839, velocity[z]=-30.139, score =585.933(best =590.127,worst =  6.854)
# Episode = 293,pose =  0.000, velocity[z]=-51.362, score =512.943(best =590.127,worst =  6.854)
# Episode = 294,pose =  0.000, velocity[z]=-45.876, score =547.830(best =590.127,worst =  6.854)
# Episode = 295,pose =  7.287, velocity[z]=-38.494, score =582.675(best =590.127,worst =  6.854)
# Episode = 296,pose =129.616, velocity[z]=-12.012, score =584.613(best =590.127,worst =  6.854)
# Episode = 297,pose =  0.724, velocity[z]=-51.459, score =578.836(best =590.127,worst =  6.854)
# Episode = 298,pose =129.474, velocity[z]=-12.305, score =586.489(best =590.127,worst =  6.854)
# Episode = 299,pose = 37.635, velocity[z]= -3.141, score =583.816(best =590.127,worst =  6.854)
# Episode = 300,pose = 10.245, velocity[z]=-38.822, score =583.939(best =590.127,worst =  6.854)
# Episode = 301,pose =  0.000, velocity[z]=-31.727, score =549.106(best =590.127,worst =  6.854)
# Episode = 302,pose =  0.000, velocity[z]=-27.268, score =581.665(best =590.127,worst =  6.854)
# Episode = 303,pose =  0.000, velocity[z]=-40.362, score =559.471(best =590.127,worst =  6.854)
# Episode = 304,pose =  0.000, velocity[z]=-52.597, score =546.518(best =590.127,worst =  6.854)
# Episode = 305,pose =  3.099, velocity[z]=-42.435, score =581.939(best =590.127,worst =  6.854)
# Episode = 306,pose =  0.000, velocity[z]=-29.783, score =568.974(best =590.127,worst =  6.854)
# Episode = 307,pose =  0.000, velocity[z]=-40.042, score =559.461(best =590.127,worst =  6.854)
# Episode = 308,pose =  0.000, velocity[z]=-38.492, score =559.478(best =590.127,worst =  6.854)
# Episode = 309,pose =  0.000, velocity[z]=-39.213, score =559.487(best =590.127,worst =  6.854)
# Episode = 310,pose =  0.000, velocity[z]=-58.440, score =553.102(best =590.127,worst =  6.854)
# Episode = 311,pose =  0.000, velocity[z]=-33.488, score =565.931(best =590.127,worst =  6.854)
# Episode = 312,pose =  0.000, velocity[z]=-40.622, score =549.479(best =590.127,worst =  6.854)
# Episode = 313,pose =  0.000, velocity[z]=-42.872, score =549.484(best =590.127,worst =  6.854)
# Episode = 314,pose =  0.000, velocity[z]=-42.992, score =559.456(best =590.127,worst =  6.854)
# Episode = 315,pose =  0.000, velocity[z]=-40.913, score =559.434(best =590.127,worst =  6.854)
# Episode = 316,pose =  0.000, velocity[z]=-40.301, score =533.069(best =590.127,worst =  6.854)
# Episode = 317,pose =  0.000, velocity[z]=-38.160, score =549.493(best =590.127,worst =  6.854)
# Episode = 318,pose =  0.000, velocity[z]=-43.339, score =559.437(best =590.127,worst =  6.854)
# Episode = 319,pose =  0.000, velocity[z]=-43.135, score =543.041(best =590.127,worst =  6.854)
# Episode = 320,pose =  0.000, velocity[z]=-41.718, score =533.047(best =590.127,worst =  6.854)
# Episode = 321,pose =  0.000, velocity[z]=-42.567, score =543.029(best =590.127,worst =  6.854)
# Episode = 322,pose =  0.000, velocity[z]=-40.315, score =533.066(best =590.127,worst =  6.854)
# Episode = 323,pose =  0.000, velocity[z]=-40.982, score =543.018(best =590.127,worst =  6.854)
# Episode = 324,pose =  0.000, velocity[z]=-42.203, score =533.046(best =590.127,worst =  6.854)
# Episode = 325,pose =  0.000, velocity[z]=-42.119, score =546.507(best =590.127,worst =  6.854)
# Episode = 326,pose =  0.000, velocity[z]=-34.795, score =578.642(best =590.127,worst =  6.854)
# Episode = 327,pose =  0.000, velocity[z]=-42.339, score =533.053(best =590.127,worst =  6.854)
# Episode = 328,pose =  0.000, velocity[z]=-43.050, score =543.051(best =590.127,worst =  6.854)
# Episode = 329,pose =  0.000, velocity[z]=-40.445, score =543.045(best =590.127,worst =  6.854)
# Episode = 330,pose =  0.000, velocity[z]=-43.509, score =543.052(best =590.127,worst =  6.854)
# Episode = 331,pose =  0.000, velocity[z]=-43.135, score =543.059(best =590.127,worst =  6.854)
# Episode = 332,pose =  0.000, velocity[z]=-40.437, score =543.063(best =590.127,worst =  6.854)
# Episode = 333,pose =  0.000, velocity[z]=-45.218, score =543.050(best =590.127,worst =  6.854)
# Episode = 334,pose =  0.000, velocity[z]=-46.305, score =543.054(best =590.127,worst =  6.854)
# Episode = 335,pose =  0.000, velocity[z]=-41.983, score =533.132(best =590.127,worst =  6.854)
# Episode = 336,pose =  0.000, velocity[z]=-46.464, score =543.065(best =590.127,worst =  6.854)
# Episode = 337,pose =  0.000, velocity[z]=-42.789, score =543.121(best =590.127,worst =  6.854)
# Episode = 338,pose =  3.602, velocity[z]=-42.203, score =580.983(best =590.127,worst =  6.854)
# Episode = 339,pose =  0.000, velocity[z]=-44.396, score =539.445(best =590.127,worst =  6.854)
# Episode = 340,pose =  0.000, velocity[z]=-40.434, score =543.181(best =590.127,worst =  6.854)
# Episode = 341,pose =  0.000, velocity[z]=-40.945, score =543.048(best =590.127,worst =  6.854)
# Episode = 342,pose =  0.000, velocity[z]=-40.447, score =543.181(best =590.127,worst =  6.854)
# Episode = 343,pose =  7.551, velocity[z]=-17.430, score =580.612(best =590.127,worst =  6.854)
# Episode = 344,pose =  0.000, velocity[z]=-47.132, score =543.293(best =590.127,worst =  6.854)
# Episode = 345,pose =  0.000, velocity[z]=-40.416, score =543.052(best =590.127,worst =  6.854)
# Episode = 346,pose =  0.000, velocity[z]=-37.638, score =565.267(best =590.127,worst =  6.854)
# Episode = 347,pose =  0.000, velocity[z]=-45.415, score =543.124(best =590.127,worst =  6.854)
# Episode = 348,pose =  0.000, velocity[z]=-40.528, score =543.038(best =590.127,worst =  6.854)
# Episode = 349,pose =  0.000, velocity[z]=-40.596, score =543.042(best =590.127,worst =  6.854)
# Episode = 350,pose =  0.000, velocity[z]=-40.745, score =552.512(best =590.127,worst =  6.854)
# Episode = 351,pose =  0.000, velocity[z]=-40.623, score =539.519(best =590.127,worst =  6.854)
# Episode = 352,pose =  0.000, velocity[z]=-46.103, score =526.502(best =590.127,worst =  6.854)
# Episode = 353,pose =154.363, velocity[z]= -2.959, score =585.285(best =590.127,worst =  6.854)
# Episode = 354,pose = 67.729, velocity[z]=-28.610, score =591.670(best =591.670,worst =  6.854)
# Episode = 355,pose =  0.000, velocity[z]=-41.686, score =563.018(best =591.670,worst =  6.854)
# Episode = 356,pose =  0.000, velocity[z]=-40.893, score =546.061(best =591.670,worst =  6.854)
# Episode = 357,pose =  0.000, velocity[z]=-36.821, score =565.599(best =591.670,worst =  6.854)
# Episode = 358,pose =  0.000, velocity[z]=-40.441, score =543.044(best =591.670,worst =  6.854)
# Episode = 359,pose =  0.000, velocity[z]=-40.880, score =543.041(best =591.670,worst =  6.854)
# Episode = 360,pose =  0.000, velocity[z]=-52.307, score =559.065(best =591.670,worst =  6.854)
# Episode = 361,pose =157.890, velocity[z]=  1.971, score =582.394(best =591.670,worst =  6.854)
# Episode = 362,pose =162.394, velocity[z]=  4.007, score =583.175(best =591.670,worst =  6.854)
# Episode = 363,pose = 17.718, velocity[z]=-37.680, score =587.650(best =591.670,worst =  6.854)
# Episode = 364,pose =  0.000, velocity[z]=-93.083, score =555.598(best =591.670,worst =  6.854)
# Episode = 365,pose =  0.000, velocity[z]=-40.558, score =543.059(best =591.670,worst =  6.854)
# Episode = 366,pose =  0.000, velocity[z]=-40.398, score =543.050(best =591.670,worst =  6.854)
# Episode = 367,pose =  0.000, velocity[z]=-40.459, score =543.046(best =591.670,worst =  6.854)
# Episode = 368,pose =  0.000, velocity[z]=-41.457, score =549.684(best =591.670,worst =  6.854)
# Episode = 369,pose =  0.000, velocity[z]=-40.436, score =543.080(best =591.670,worst =  6.854)
# Episode = 370,pose =  0.000, velocity[z]=-47.777, score =559.672(best =591.670,worst =  6.854)
# Episode = 371,pose =172.052, velocity[z]= 15.930, score =583.999(best =591.670,worst =  6.854)
# Episode = 372,pose = 89.292, velocity[z]=-23.771, score =590.809(best =591.670,worst =  6.854)
# Episode = 373,pose =  4.422, velocity[z]=-31.885, score =581.810(best =591.670,worst =  6.854)
# Episode = 374,pose =  0.000, velocity[z]=-40.438, score =543.199(best =591.670,worst =  6.854)
# Episode = 375,pose =  0.000, velocity[z]=-40.426, score =543.060(best =591.670,worst =  6.854)
# Episode = 376,pose =  0.000, velocity[z]=-56.669, score =543.189(best =591.670,worst =  6.854)
# Episode = 377,pose =  0.000, velocity[z]=-40.637, score =543.045(best =591.670,worst =  6.854)
# Episode = 378,pose =  0.000, velocity[z]=-40.760, score =543.051(best =591.670,worst =  6.854)
# Episode = 379,pose =  0.000, velocity[z]=-40.339, score =543.071(best =591.670,worst =  6.854)
# Episode = 380,pose =  0.000, velocity[z]=-40.451, score =543.092(best =591.670,worst =  6.854)
# Episode = 381,pose =  0.000, velocity[z]=-45.185, score =559.515(best =591.670,worst =  6.854)
# Episode = 382,pose =  0.000, velocity[z]=-44.390, score =552.883(best =591.670,worst =  6.854)
# Episode = 383,pose =  0.000, velocity[z]=-36.101, score =548.320(best =591.670,worst =  6.854)
# Episode = 384,pose =  0.000, velocity[z]=-43.667, score =583.940(best =591.670,worst =  6.854)
# Episode = 385,pose =  0.000, velocity[z]=-36.259, score =546.082(best =591.670,worst =  6.854)
# Episode = 386,pose =  0.000, velocity[z]=-57.144, score =555.338(best =591.670,worst =  6.854)
# Episode = 387,pose = 28.782, velocity[z]=-27.263, score =583.744(best =591.670,worst =  6.854)
# Episode = 388,pose =168.993, velocity[z]= 13.929, score =583.011(best =591.670,worst =  6.854)
# Episode = 389,pose =172.401, velocity[z]= 15.974, score =584.327(best =591.670,worst =  6.854)
# Episode = 390,pose =156.644, velocity[z]=  0.198, score =582.683(best =591.670,worst =  6.854)
# Episode = 391,pose =174.700, velocity[z]= 19.493, score =584.085(best =591.670,worst =  6.854)
# Episode = 392,pose =164.038, velocity[z]=  8.503, score =582.673(best =591.670,worst =  6.854)
# Episode = 393,pose =172.876, velocity[z]= 17.363, score =583.815(best =591.670,worst =  6.854)
# Episode = 394,pose =167.257, velocity[z]=  8.806, score =583.610(best =591.670,worst =  6.854)
# Episode = 395,pose =121.481, velocity[z]=-14.680, score =587.132(best =591.670,worst =  6.854)
# Episode = 396,pose =  0.000, velocity[z]=-36.960, score =533.045(best =591.670,worst =  6.854)
# Episode = 397,pose =  0.000, velocity[z]=-39.409, score =559.439(best =591.670,worst =  6.854)
# Episode = 398,pose =  0.000, velocity[z]=-35.447, score =539.493(best =591.670,worst =  6.854)
# Episode = 399,pose =  0.000, velocity[z]=-35.646, score =555.542(best =591.670,worst =  6.854)
# Episode = 400,pose =  0.000, velocity[z]=-38.495, score =539.511(best =591.670,worst =  6.854)
# Episode = 401,pose =  0.000, velocity[z]=-37.891, score =565.946(best =591.670,worst =  6.854)
# Episode = 402,pose =  0.000, velocity[z]=-44.330, score =533.056(best =591.670,worst =  6.854)
# Episode = 403,pose =  0.000, velocity[z]=-53.391, score =526.673(best =591.670,worst =  6.854)
# Episode = 404,pose =  0.000, velocity[z]=-41.171, score =533.043(best =591.670,worst =  6.854)
# Episode = 405,pose =  0.000, velocity[z]=-45.956, score =526.733(best =591.670,worst =  6.854)
# Episode = 406,pose =  0.000, velocity[z]=-40.067, score =565.945(best =591.670,worst =  6.854)
# Episode = 407,pose =  0.000, velocity[z]=-55.736, score =539.058(best =591.670,worst =  6.854)
# Episode = 408,pose =  0.000, velocity[z]=-40.688, score =549.500(best =591.670,worst =  6.854)
# Episode = 409,pose =  0.000, velocity[z]=-37.891, score =559.427(best =591.670,worst =  6.854)
# Episode = 410,pose =  0.000, velocity[z]=-31.793, score =559.449(best =591.670,worst =  6.854)
# Episode = 411,pose =134.086, velocity[z]=-10.727, score =587.419(best =591.670,worst =  6.854)
# Episode = 412,pose =  0.000, velocity[z]=-38.409, score =533.048(best =591.670,worst =  6.854)
# Episode = 413,pose =  0.000, velocity[z]=-52.021, score =529.921(best =591.670,worst =  6.854)
# Episode = 414,pose =  0.000, velocity[z]=-42.402, score =536.116(best =591.670,worst =  6.854)
# Episode = 415,pose =  0.000, velocity[z]=-37.772, score =533.071(best =591.670,worst =  6.854)
# Episode = 416,pose =  0.000, velocity[z]=-38.833, score =559.498(best =591.670,worst =  6.854)
# Episode = 417,pose = 29.479, velocity[z]=-15.372, score =584.642(best =591.670,worst =  6.854)
# Episode = 418,pose =  0.000, velocity[z]=-31.374, score =562.502(best =591.670,worst =  6.854)
# Episode = 419,pose =  0.000, velocity[z]=-33.356, score =552.790(best =591.670,worst =  6.854)
# Episode = 420,pose =  0.000, velocity[z]=-36.299, score =565.939(best =591.670,worst =  6.854)
# Episode = 421,pose =  0.000, velocity[z]=-45.315, score =533.156(best =591.670,worst =  6.854)
# Episode = 422,pose =  0.000, velocity[z]=-108.802, score =500.561(best =591.670,worst =  6.854)
# Episode = 423,pose =  0.000, velocity[z]=-85.476, score =520.289(best =591.670,worst =  6.854)
# Episode = 424,pose =  0.000, velocity[z]=-41.457, score =539.574(best =591.670,worst =  6.854)
# Episode = 425,pose =  0.000, velocity[z]=-44.507, score =465.300(best =591.670,worst =  6.854)
# Episode = 426,pose =  0.000, velocity[z]=-42.995, score =552.004(best =591.670,worst =  6.854)
# Episode = 427,pose =  0.000, velocity[z]=-96.854, score =486.926(best =591.670,worst =  6.854)
# Episode = 428,pose =  0.000, velocity[z]=-37.877, score =566.046(best =591.670,worst =  6.854)
# Episode = 429,pose =  0.000, velocity[z]=-36.726, score =565.136(best =591.670,worst =  6.854)
# Episode = 430,pose =  0.000, velocity[z]=-43.369, score =538.097(best =591.670,worst =  6.854)
# Episode = 431,pose =  0.000, velocity[z]=-58.326, score =526.621(best =591.670,worst =  6.854)
# Episode = 432,pose =  0.000, velocity[z]=-36.211, score =546.408(best =591.670,worst =  6.854)
# Episode = 433,pose =  0.000, velocity[z]=-43.373, score =549.483(best =591.670,worst =  6.854)
# Episode = 434,pose =  0.000, velocity[z]=-41.745, score =549.273(best =591.670,worst =  6.854)
# Episode = 435,pose =  0.000, velocity[z]=-193.217, score =504.629(best =591.670,worst =  6.854)
# Episode = 436,pose =  0.000, velocity[z]=-58.947, score =519.702(best =591.670,worst =  6.854)
# Episode = 437,pose =  0.000, velocity[z]=-52.297, score =552.333(best =591.670,worst =  6.854)
# Episode = 438,pose =  0.000, velocity[z]=-44.836, score =541.639(best =591.670,worst =  6.854)
# Episode = 439,pose =130.713, velocity[z]=-11.710, score =585.305(best =591.670,worst =  6.854)
# Episode = 440,pose =  0.000, velocity[z]=-62.452, score =525.334(best =591.670,worst =  6.854)
# Episode = 441,pose =  0.000, velocity[z]=-47.830, score =549.593(best =591.670,worst =  6.854)
# Episode = 442,pose =  0.000, velocity[z]=-61.461, score =584.929(best =591.670,worst =  6.854)
# Episode = 443,pose =  0.000, velocity[z]=-57.010, score =502.922(best =591.670,worst =  6.854)
# Episode = 444,pose =  0.000, velocity[z]=-54.499, score =526.776(best =591.670,worst =  6.854)
# Episode = 445,pose =  2.329, velocity[z]=-16.678, score =581.588(best =591.670,worst =  6.854)
# Episode = 446,pose =  0.000, velocity[z]=-37.176, score =533.361(best =591.670,worst =  6.854)
# Episode = 447,pose =  1.516, velocity[z]=-41.212, score =583.108(best =591.670,worst =  6.854)
# Episode = 448,pose =  1.888, velocity[z]=-30.019, score =581.915(best =591.670,worst =  6.854)
# Episode = 449,pose =  0.000, velocity[z]=-42.254, score =551.711(best =591.670,worst =  6.854)
# Episode = 450,pose =  0.000, velocity[z]=-115.629, score =481.499(best =591.670,worst =  6.854)
# Episode = 451,pose =  0.000, velocity[z]=-56.947, score =491.874(best =591.670,worst =  6.854)
# Episode = 452,pose =  0.000, velocity[z]=-33.445, score =585.598(best =591.670,worst =  6.854)
# Episode = 453,pose =  0.000, velocity[z]=-53.022, score =548.546(best =591.670,worst =  6.854)
# Episode = 454,pose =  0.000, velocity[z]=-33.380, score =552.566(best =591.670,worst =  6.854)
# Episode = 455,pose =  0.000, velocity[z]=-64.758, score =553.113(best =591.670,worst =  6.854)
# Episode = 456,pose =  0.000, velocity[z]=-69.716, score =533.168(best =591.670,worst =  6.854)
# Episode = 457,pose =  0.000, velocity[z]=-38.461, score =565.789(best =591.670,worst =  6.854)
# Episode = 458,pose =  0.000, velocity[z]=-45.315, score =585.905(best =591.670,worst =  6.854)
# Episode = 459,pose =  0.000, velocity[z]=-42.193, score =568.454(best =591.670,worst =  6.854)
# Episode = 460,pose =  0.000, velocity[z]=-37.275, score =457.618(best =591.670,worst =  6.854)
# Episode = 461,pose =  0.000, velocity[z]=-86.723, score =586.799(best =591.670,worst =  6.854)
# Episode = 462,pose =  0.000, velocity[z]=-72.545, score =526.494(best =591.670,worst =  6.854)
# Episode = 463,pose =  0.000, velocity[z]=-34.991, score =561.919(best =591.670,worst =  6.854)
# Episode = 464,pose =  0.000, velocity[z]=-28.969, score =569.092(best =591.670,worst =  6.854)
# Episode = 465,pose =  0.000, velocity[z]=-36.051, score =545.586(best =591.670,worst =  6.854)
# Episode = 466,pose =  0.000, velocity[z]=-40.137, score =556.013(best =591.670,worst =  6.854)
# Episode = 467,pose =  0.000, velocity[z]=-46.692, score =569.256(best =591.670,worst =  6.854)
# Episode = 468,pose =  0.000, velocity[z]=-28.375, score =584.644(best =591.670,worst =  6.854)
# Episode = 469,pose =  0.000, velocity[z]=-58.475, score =518.412(best =591.670,worst =  6.854)
# Episode = 470,pose = 13.877, velocity[z]=-39.481, score =584.905(best =591.670,worst =  6.854)
# Episode = 471,pose =  0.000, velocity[z]=-63.727, score =559.799(best =591.670,worst =  6.854)
# Episode = 472,pose =  0.000, velocity[z]=-43.669, score =505.700(best =591.670,worst =  6.854)
# Episode = 473,pose =  0.000, velocity[z]=-32.576, score =563.815(best =591.670,worst =  6.854)
# Episode = 474,pose =  0.000, velocity[z]=-61.830, score =503.644(best =591.670,worst =  6.854)
# Episode = 475,pose =  0.000, velocity[z]=-41.380, score =562.833(best =591.670,worst =  6.854)
# Episode = 476,pose =  0.000, velocity[z]=-33.093, score =558.207(best =591.670,worst =  6.854)
# Episode = 477,pose =  0.000, velocity[z]=-68.955, score =480.309(best =591.670,worst =  6.854)
# Episode = 478,pose =  0.000, velocity[z]=-82.220, score =425.567(best =591.670,worst =  6.854)
# Episode = 479,pose =  0.000, velocity[z]=-70.104, score =500.891(best =591.670,worst =  6.854)
# Episode = 480,pose =  0.000, velocity[z]=-57.299, score =505.344(best =591.670,worst =  6.854)
# Episode = 481,pose = 20.678, velocity[z]=-28.050, score =584.459(best =591.670,worst =  6.854)
# Episode = 482,pose =  0.000, velocity[z]=-24.370, score =510.991(best =591.670,worst =  6.854)
# Episode = 483,pose =  0.000, velocity[z]=-52.280, score =466.485(best =591.670,worst =  6.854)
# Episode = 484,pose =  0.000, velocity[z]=-32.861, score =578.226(best =591.670,worst =  6.854)
# Episode = 485,pose = 18.640, velocity[z]=-15.914, score =581.715(best =591.670,worst =  6.854)
# Episode = 486,pose = 61.846, velocity[z]=-14.447, score =582.328(best =591.670,worst =  6.854)
# Episode = 487,pose =  0.000, velocity[z]=-48.527, score =492.678(best =591.670,worst =  6.854)
# Episode = 488,pose =  0.000, velocity[z]=-45.153, score =466.086(best =591.670,worst =  6.854)
# Episode = 489,pose =  0.000, velocity[z]=-46.414, score =505.781(best =591.670,worst =  6.854)
# Episode = 490,pose =  0.000, velocity[z]=-86.347, score =459.059(best =591.670,worst =  6.854)
# Episode = 491,pose =  0.000, velocity[z]=-41.844, score =544.296(best =591.670,worst =  6.854)
# Episode = 492,pose =  0.000, velocity[z]=-81.695, score =527.292(best =591.670,worst =  6.854)
# Episode = 493,pose =  0.000, velocity[z]=-45.818, score =545.749(best =591.670,worst =  6.854)
# Episode = 494,pose =  0.000, velocity[z]=-174.097, score =521.239(best =591.670,worst =  6.854)
# Episode = 495,pose =  0.000, velocity[z]=-75.048, score =499.949(best =591.670,worst =  6.854)
# Episode = 496,pose =  0.000, velocity[z]=-40.444, score =537.196(best =591.670,worst =  6.854)
# Episode = 497,pose =  0.000, velocity[z]=-38.796, score =475.933(best =591.670,worst =  6.854)
# Episode = 498,pose =  0.000, velocity[z]=-31.074, score =585.301(best =591.670,worst =  6.854)
# Episode = 499,pose =  0.000, velocity[z]=-38.411, score =535.742(best =591.670,worst =  6.854)
# Episode = 500,pose =  0.000, velocity[z]=-65.016, score =529.757(best =591.670,worst =  6.854)
# Episode = 501,pose =  0.000, velocity[z]=-62.693, score =536.064(best =591.670,worst =  6.854)
# Episode = 502,pose =  0.000, velocity[z]=-37.343, score =580.124(best =591.670,worst =  6.854)
# Episode = 503,pose =  0.000, velocity[z]=-64.747, score =498.550(best =591.670,worst =  6.854)
# Episode = 504,pose =  0.000, velocity[z]=-54.726, score =538.299(best =591.670,worst =  6.854)
# Episode = 505,pose =  0.000, velocity[z]=-90.018, score =545.306(best =591.670,worst =  6.854)
# Episode = 506,pose =  0.000, velocity[z]=-249.385, score =390.605(best =591.670,worst =  6.854)
# Episode = 507,pose = 32.126, velocity[z]=-24.268, score =585.296(best =591.670,worst =  6.854)
# Episode = 508,pose =  0.000, velocity[z]=-70.018, score =552.728(best =591.670,worst =  6.854)
# Episode = 509,pose = 18.912, velocity[z]=-37.194, score =583.573(best =591.670,worst =  6.854)
# Episode = 510,pose =  0.000, velocity[z]=-34.029, score =549.627(best =591.670,worst =  6.854)
# Episode = 511,pose =  0.000, velocity[z]=-40.519, score =548.734(best =591.670,worst =  6.854)
# Episode = 512,pose = 10.859, velocity[z]=-40.045, score =585.860(best =591.670,worst =  6.854)
# Episode = 513,pose =  0.000, velocity[z]=-77.389, score =562.101(best =591.670,worst =  6.854)
# Episode = 514,pose =  0.000, velocity[z]=-39.493, score =508.657(best =591.670,worst =  6.854)
# Episode = 515,pose = 70.361, velocity[z]=-27.863, score =591.167(best =591.670,worst =  6.854)
# Episode = 516,pose =  0.000, velocity[z]=-47.127, score =556.143(best =591.670,worst =  6.854)
# Episode = 517,pose =  2.724, velocity[z]=-39.752, score =583.574(best =591.670,worst =  6.854)
# Episode = 518,pose =  0.000, velocity[z]=-42.848, score =582.082(best =591.670,worst =  6.854)
# Episode = 519,pose =  0.000, velocity[z]=-31.994, score =534.801(best =591.670,worst =  6.854)
# Episode = 520,pose =  0.000, velocity[z]=-49.964, score =559.506(best =591.670,worst =  6.854)
# Episode = 521,pose =  0.000, velocity[z]=-33.620, score =565.891(best =591.670,worst =  6.854)
# Episode = 522,pose =  0.000, velocity[z]=-66.720, score =417.981(best =591.670,worst =  6.854)
# Episode = 523,pose =  0.000, velocity[z]=-531.562, score =301.110(best =591.670,worst =  6.854)
# Episode = 524,pose =  0.000, velocity[z]=-40.653, score =452.307(best =591.670,worst =  6.854)
# Episode = 525,pose =  0.000, velocity[z]=-42.708, score =572.651(best =591.670,worst =  6.854)
# Episode = 526,pose =  0.000, velocity[z]=-133.343, score =501.331(best =591.670,worst =  6.854)
# Episode = 527,pose =  0.000, velocity[z]=-136.363, score =471.106(best =591.670,worst =  6.854)
# Episode = 528,pose =  0.000, velocity[z]=-38.479, score =552.466(best =591.670,worst =  6.854)
# Episode = 529,pose =  7.523, velocity[z]=-41.843, score =582.444(best =591.670,worst =  6.854)
# Episode = 530,pose =  0.000, velocity[z]=-36.761, score =566.020(best =591.670,worst =  6.854)
# Episode = 531,pose =  0.000, velocity[z]=-42.285, score =559.492(best =591.670,worst =  6.854)
# Episode = 532,pose =  0.000, velocity[z]=-43.631, score =533.087(best =591.670,worst =  6.854)
# Episode = 533,pose =  0.000, velocity[z]=-42.663, score =575.965(best =591.670,worst =  6.854)
# Episode = 534,pose =  0.000, velocity[z]=-42.970, score =556.507(best =591.670,worst =  6.854)
# Episode = 535,pose =  0.000, velocity[z]=-36.101, score =559.525(best =591.670,worst =  6.854)
# Episode = 536,pose =  0.000, velocity[z]=-47.544, score =569.080(best =591.670,worst =  6.854)
# Episode = 537,pose =  0.000, velocity[z]=-43.567, score =549.543(best =591.670,worst =  6.854)
# Episode = 538,pose =  0.000, velocity[z]=-44.381, score =536.624(best =591.670,worst =  6.854)
# Episode = 539,pose =  0.000, velocity[z]=-35.536, score =566.176(best =591.670,worst =  6.854)
# Episode = 540,pose =  0.000, velocity[z]=-45.472, score =559.515(best =591.670,worst =  6.854)
# Episode = 541,pose =  0.000, velocity[z]=-38.926, score =559.480(best =591.670,worst =  6.854)
# Episode = 542,pose =  0.000, velocity[z]=-39.322, score =533.114(best =591.670,worst =  6.854)
# Episode = 543,pose =  0.000, velocity[z]=-36.845, score =559.410(best =591.670,worst =  6.854)
# Episode = 544,pose =  0.000, velocity[z]=-45.181, score =549.289(best =591.670,worst =  6.854)
# Episode = 545,pose =  0.000, velocity[z]=-41.089, score =546.298(best =591.670,worst =  6.854)
# Episode = 546,pose =  0.000, velocity[z]=-40.696, score =559.466(best =591.670,worst =  6.854)
# Episode = 547,pose =  0.000, velocity[z]=-39.830, score =533.099(best =591.670,worst =  6.854)
# Episode = 548,pose =  0.000, velocity[z]=-43.203, score =542.922(best =591.670,worst =  6.854)
# Episode = 549,pose =  0.000, velocity[z]=-40.474, score =549.489(best =591.670,worst =  6.854)
# Episode = 550,pose =  0.000, velocity[z]=-45.345, score =559.667(best =591.670,worst =  6.854)
# Episode = 551,pose =  0.000, velocity[z]=-45.860, score =552.807(best =591.670,worst =  6.854)
# Episode = 552,pose =  0.000, velocity[z]=-43.123, score =559.501(best =591.670,worst =  6.854)
# Episode = 553,pose =  0.000, velocity[z]=-43.512, score =559.268(best =591.670,worst =  6.854)
# Episode = 554,pose =  0.000, velocity[z]=-47.183, score =559.472(best =591.670,worst =  6.854)
# Episode = 555,pose =  0.000, velocity[z]=-100.346, score =513.853(best =591.670,worst =  6.854)
# Episode = 556,pose =  0.000, velocity[z]=-39.654, score =549.501(best =591.670,worst =  6.854)
# Episode = 557,pose =  0.000, velocity[z]=-36.807, score =559.498(best =591.670,worst =  6.854)
# Episode = 558,pose =  0.000, velocity[z]=-41.866, score =526.442(best =591.670,worst =  6.854)
# Episode = 559,pose =  0.000, velocity[z]=-38.985, score =559.337(best =591.670,worst =  6.854)
# Episode = 560,pose =  0.000, velocity[z]=-34.341, score =566.006(best =591.670,worst =  6.854)
# Episode = 561,pose =  0.000, velocity[z]=-35.585, score =566.004(best =591.670,worst =  6.854)
# Episode = 562,pose =  0.000, velocity[z]=-43.156, score =526.225(best =591.670,worst =  6.854)
# Episode = 563,pose =  0.000, velocity[z]=-40.756, score =572.619(best =591.670,worst =  6.854)
# Episode = 564,pose =  0.000, velocity[z]=-37.760, score =532.852(best =591.670,worst =  6.854)
# Episode = 565,pose =  0.000, velocity[z]=-44.584, score =549.453(best =591.670,worst =  6.854)
# Episode = 566,pose =  0.000, velocity[z]=-45.931, score =549.508(best =591.670,worst =  6.854)
# Episode = 567,pose =  0.000, velocity[z]=-35.120, score =569.319(best =591.670,worst =  6.854)
# Episode = 568,pose =  0.000, velocity[z]=-46.313, score =536.226(best =591.670,worst =  6.854)
# Episode = 569,pose =  0.000, velocity[z]=-53.020, score =549.666(best =591.670,worst =  6.854)
# Episode = 570,pose =  0.000, velocity[z]=-47.357, score =539.849(best =591.670,worst =  6.854)
# Episode = 571,pose =  0.000, velocity[z]=-43.371, score =559.537(best =591.670,worst =  6.854)
# Episode = 572,pose =  0.000, velocity[z]=-38.817, score =559.488(best =591.670,worst =  6.854)
# Episode = 573,pose =  0.000, velocity[z]=-40.745, score =559.465(best =591.670,worst =  6.854)
# Episode = 574,pose =  0.000, velocity[z]=-39.453, score =542.897(best =591.670,worst =  6.854)
# Episode = 575,pose =  0.000, velocity[z]=-45.671, score =549.523(best =591.670,worst =  6.854)
# Episode = 576,pose =  0.000, velocity[z]=-38.917, score =549.550(best =591.670,worst =  6.854)
# Episode = 577,pose =  0.000, velocity[z]=-35.620, score =539.446(best =591.670,worst =  6.854)
# Episode = 578,pose =  0.000, velocity[z]=-47.768, score =539.418(best =591.670,worst =  6.854)
# Episode = 579,pose =  0.000, velocity[z]=-40.460, score =533.107(best =591.670,worst =  6.854)
# Episode = 580,pose =  0.000, velocity[z]=-34.920, score =539.542(best =591.670,worst =  6.854)
# Episode = 581,pose =  0.000, velocity[z]=-43.645, score =592.361(best =592.361,worst =  6.854)
# Episode = 582,pose =  0.000, velocity[z]=-45.224, score =532.938(best =592.361,worst =  6.854)
# Episode = 583,pose =  0.000, velocity[z]=-40.570, score =572.604(best =592.361,worst =  6.854)
# Episode = 584,pose =  0.000, velocity[z]=-34.615, score =542.480(best =592.361,worst =  6.854)
# Episode = 585,pose =  0.000, velocity[z]=-38.167, score =552.948(best =592.361,worst =  6.854)
# Episode = 586,pose =170.703, velocity[z]= 12.890, score =582.640(best =592.361,worst =  6.854)
# Episode = 587,pose =  0.000, velocity[z]=-35.201, score =539.588(best =592.361,worst =  6.854)
# Episode = 588,pose = 33.249, velocity[z]=-38.453, score =589.272(best =592.361,worst =  6.854)
# Episode = 589,pose =130.196, velocity[z]= -7.579, score =578.913(best =592.361,worst =  6.854)
# Episode = 590,pose =  0.000, velocity[z]=-40.644, score =549.565(best =592.361,worst =  6.854)
# Episode = 591,pose =  0.000, velocity[z]=-40.429, score =545.806(best =592.361,worst =  6.854)
# Episode = 592,pose = 15.037, velocity[z]=-22.586, score =582.804(best =592.361,worst =  6.854)
# Episode = 593,pose =  0.000, velocity[z]=-111.296, score =291.657(best =592.361,worst =  6.854)
# Episode = 594,pose =  0.000, velocity[z]=-44.299, score =504.914(best =592.361,worst =  6.854)
# Episode = 595,pose = 84.637, velocity[z]=-27.836, score =590.491(best =592.361,worst =  6.854)
# Episode = 596,pose =  0.000, velocity[z]=-129.709, score =489.870(best =592.361,worst =  6.854)
# Episode = 597,pose = 74.862, velocity[z]=-74.614, score =579.831(best =592.361,worst =  6.854)
# Episode = 598,pose =155.373, velocity[z]= -0.335, score =584.367(best =592.361,worst =  6.854)
# Episode = 599,pose =164.123, velocity[z]=  6.000, score =584.137(best =592.361,worst =  6.854)
# Episode = 600,pose = 38.997, velocity[z]=-33.512, score =587.728(best =592.361,worst =  6.854)

# %%
plot_run(results)

# %%
path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=target_pos)

# %% [markdown]
# ## 绘制阶段奖励
#
# 请绘制智能体在每个阶段中获得的总奖励，这可以是单次运行的奖励值，也可以是多次运行的平均值。

# %%
## TODO: Plot the rewards.
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_rewards(rewards):

    plt.title('rewards')
    plt.xlabel('episode')
    plt.ylabel('rewards')
    
    plt.plot(rewards['episode'], rewards['reward'], label='reward/episode')
    plt.legend()
    _ = plt.ylim()

# %%
plot_rewards(rewards)

# %% [markdown]
# ## 回顾
#
# **问题 1**：请描述你在 `task.py` 中指定的任务。你如何设计奖励函数？
#
# **回答**：
# 在quadcopter_task.py中定义的主要任务是设定到达目标位置(0，0，100)
#
# 实际位置与目标位置相差越小，获得的奖励值越大，为了避免奖励函数梯度爆炸造成不稳定，使用tanh把每次的奖励限定在(-1,1)范围内。
# 通过调试， takeoff任务最终确定的奖励函数：reward = np.tanh(1 - 0.003*(abs(self.sim.pose[:3] - self.target_pos))).sum()

# %% [markdown]
# **问题 2**：请简要描述你的智能体，你可以参考以下问题：
#
# - 你尝试了哪些学习算法？哪个效果最好？
# - 你最终选择了哪些超参数（比如 $\alpha$，$\gamma$，$\epsilon$ 等）？
# - 你使用了什么样的神经网络结构（如果有的话）？请说明层数、大小和激活函数等信息。
#
# **回答**：
#
#
# 1.我的学习算法是参考深度确定性策略梯度算法，简称 DDPG。该算法适合与连续状态空间
#
# 2.选择超参数：
# exploration_mu = 0
# exploration_theta = 0.15
# exploration_sigma = 0.2
# self.buffer_size = 100000
# self.batch_size = 64
# gamma = 0.99
# tau = 0.01
#
# 3.所用神经网络结构
# Actor:
#
# Dense(units=100) + BatchNorm + L2 Regularisation + ReLu Activation
# Dense(units=200) + BatchNorm + L2 Regularisation + ReLu Activation
# Dense(units=self.actionsize) + Sigmoid Activation
# Critic:
#
# states part:
# Dense(units=100) + BatchNorm + L2 Regularisation + ReLu Activation
# Dense(units=200) + BatchNorm + L2 Regularisation + ReLu Activation
# action part:
# Dense(units=100) + BatchNorm + L2 Regularisation + ReLu Activation
# Dense(units=200) + BatchNorm + L2 Regularisation + ReLu Activation
# Combining : Add with ReLu Activation

# %% [markdown]
# **问题 3**：根据你绘制的奖励图，描述智能体的学习状况。
#
# - 学习该任务是简单还是困难？
# - 该学习曲线中是否存在循序渐进或急速上升的部分？
# - 该智能体的最终性能有多好？（比如最后十个阶段的平均奖励值）
#
# **回答**：

# %%
print("Final Performance (Mean Reward over last 10 episodes): {}".format(np.sum(rewards['reward'][-10:])/10))
# Out:
# Final Performance (Mean Reward over last 10 episodes): 572.0940016456152

# %% [markdown]
# **问题 4**：请简要总结你的本次项目经历。你可以参考以下问题：
#
# - 本次项目中最困难的部分是什么？（例如开始项目、运行 ROS、绘制、特定的任务等。）
# - 关于四轴飞行器和你的智能体的行为，你是否有一些有趣的发现？
#
# **回答**：
#
# 1.最大的困难在于对连续空间深度学习概念的理解。以及对DDPG算法的理解，参数调试。
#
# 2.获得的奖励小于400，会导致起飞失败

# %% [markdown]
# ### (可选)Plot Actor 及 Critic 结构
# 建议使用 ```from keras.utils import plot_model``` 来显示模型结构；
