# %% [markdown]
# # 项目：指导四轴飞行器学会飞行
#
# 设计一个能够使四轴飞行器飞行的智能体，然后使用你选择的强化学习算法训练它！
#
# 请尝试运用你在这一单元中学到的知识，看看哪个方法效果最好，当然你也可以自己想出创新型方法并测试它们。
# ## 说明
#
# 请查看目录下的文件，以更好地了解项目结构。
#
# - `task.py`：在本文件中定义你的任务（环境）。
# - `agents/`：本文件夹中包含强化学习智能体。
#     - `policy_search.py`：我们为你提供了一个智能体模板。
#     - `agent.py`：在本文件中开发你的智能体。
# - `physics_sim.py`：本文件中包含四轴飞行器模拟器。**请勿修改本文件**。
#
# 在本项目中，你需要在 `task.py` 中定义你的任务。尽管我们为你提供了一个任务示例，来帮助你开始项目，但你也可以随意更改这个文件。在这个 notebook 中，你还将学习更多有关修改这个文件的知识。
#
# 你还需要在 `agent.py` 中设计一个强化学习智能体，来完成你选择的任务。
#
# 我们也鼓励你创建其他文件，来帮助你整理代码。比如，你也许可以通过定义一个 `model.py` 文件来定义其他你需要的神经网络结构。
#
# ## 控制四轴飞行器
#
# 在下方的代码中，我们提供了一个智能体示例，来示范如何使用模拟器来控制四轴飞行器。这个智能体比你在 notebook 中需要测试的智能体（在 `agents/policy_search.py` 中）更加简单！
#
# 这个智能体通过设置飞行器四个轴上的转速来控制飞行器。`Basic_Agent` 类中提供的智能体将会随机为四个轴指定动作。这四个速度将通过 `act` 方法以四个浮点数列表的形式返回。
#
# 在本项目中，你将在 `agents/agent.py` 中实现的智能体会以更加智能的方法进行指定的动作。

# %% [markdown]
# ### plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_run(results, standalone=True):
    if standalone:
        plt.subplots(figsize=(15, 15))
    
    #查看四轴飞行器的位置变化
    plt.subplot(3, 3, 1)
    plt.title('Position')
    plt.plot(results['time'], results['x'], label='x')
    plt.plot(results['time'], results['y'], label='y')
    plt.plot(results['time'], results['z'], label='z')
    plt.xlabel('time, seconds')
    plt.ylabel('Position')
    plt.grid(True)
    if standalone:
        plt.legend()

    #四轴飞行器的速度
    plt.subplot(3, 3, 2)
    plt.title('Velocity')
    plt.plot(results['time'], results['x_velocity'], label='x_hat')
    plt.plot(results['time'], results['y_velocity'], label='y_hat')
    plt.plot(results['time'], results['z_velocity'], label='z_hat')
    plt.xlabel('time, seconds')
    plt.ylabel('Velocity')
    plt.grid(True)
    if standalone:
        plt.legend()
    
    #绘制欧拉角 (Euler angles)（四轴飞行器围绕 x，y 和 z 轴的旋转）的图表
    plt.subplot(3, 3, 3)
    plt.title('Orientation')
    plt.plot(results['time'], results['phi'], label='phi')
    plt.plot(results['time'], results['theta'], label='theta')
    plt.plot(results['time'], results['psi'], label='psi')
    plt.xlabel('time, seconds')
    plt.grid(True)
    if standalone:
        plt.legend()
    
    #绘制每个欧拉角的速度（每秒的弧度）图
    plt.subplot(3, 3, 4)
    plt.title('Angular Velocity')
    plt.plot(results['time'], results['phi_velocity'], label='phi')
    plt.plot(results['time'], results['theta_velocity'], label='theta')
    plt.plot(results['time'], results['psi_velocity'], label='psi')
    plt.xlabel('time, seconds')
    plt.grid(True)
    if standalone:
        plt.legend()

    #最后，你可以使用下方代码来输出智能体选择的动作。
    plt.subplot(3, 3, 5)
    plt.title('Rotor Speed')
    plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1')
    plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2')
    plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3')
    plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4')
    plt.xlabel('time, seconds')
    plt.ylabel('Rotor Speed, revolutions / second')
    plt.grid(True)
    if standalone:
        plt.legend()

    if standalone:
        plt.tight_layout()
        plt.show()

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D


def plot_point3d(ax, x, y, z, **kwargs):
    ax.scatter([x], [y], [z], **kwargs)
    ax.text(x, y, z, "({:.1f}, {:.1f}, {:.1f})".format(x, y, z))


def show_flight_path(results, target=None):
    results = np.array(results)
    
    fig = plt.figure(figsize=(10,10))
    ax = fig.gca(projection='3d')
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')

    ax.plot3D(results[:, 0], results[:, 1], results[:, 2], 'gray')
    
    if target is not None:
        plot_point3d(ax, *target[0:3], c='y', marker='x', s=100, label='target')
        
    plot_point3d(ax, *results[0, 0:3], c='g', marker='o', s=50, label='start')
    plot_point3d(ax, *results[-1, 0:3], c='r', marker='o', s=50, label='end')
    
    ax.legend()

# %% [markdown]
# ### random Agent

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# 运行下方代码，让智能体指定动作来控制四轴飞行器。
#
# 请随意更改我们提供的 `runtime`，`init_pose`，`init_velocities` 和 `init_angle_velocities` 值来更改四轴飞行器的初始条件。
#
# 下方的 `labels` 列表为模拟数据的注释。所有的信息都储存在 `data.txt` 文档中，并保存在 `results` 目录下。

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %%
plot_run(results)

# %%
path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=None)

# %% [markdown]
# 在指定任务之前，你需要在模拟器中衍生环境状态。运行下方代码来在模拟结束时输出以下变量值：
#
# - `task.sim.pose`：四周飞行器在 ($x,y,z$) 坐标系中的位置和欧拉角。
# - `task.sim.v`：四轴飞行器在 ($x,y,z$) 坐标系中的速度。
# - `task.sim.angular_v`：三个欧拉角的弧度/每秒。

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [-6.88655148 -1.84537341 31.81388714  6.10811165  0.09515469  0.        ]
# [-3.81743143 -2.6034518   5.75455683]
# [-0.04904959  0.01814695  0.        ]

# %% [markdown]
# 在 `task.py` 中的任务示例中，我们使用了四轴飞行器六个维度的动作来构建每个时间步的环境状态。然而，你也可以按照自己的意愿更改任务，你可以添加速度信息来扩大状态向量，也可以使用任何动作、速度和角速度的组合，并构造适用于你的任务的环境状态。
#
# ## 任务
#
# 在 `task.py` 中，我们为你提供了一个任务示例。请在新窗口中打开这个文件。
#
# 使用 `__init__()` 方法来初始化指定本任务所需的几个变量。
#
# - 模拟器作为 `PhysicsSim` 类（来自 `physics_sim.py` 文件）的示例进行初始化。
# - 受到 DDPG 论文中研究方法的启发，我们使用了重复调用动作的方法。对于智能体的每一个时间步，我们将利用 `action_repeats` 时间步来进行模拟。如果你并不熟悉这种方法，可以阅读 [DDPG 论文](https://arxiv.org/abs/1509.02971)的结论部分。
# - 我们设置了状态向量中每个分量的数值。在任务示例中，我们只设置了六个维度的动作信息。为了设定向量大小（`state_size`），我们必须考虑重复的动作。
# - 任务环境通常是一个四维动作空间，每个轴有一个输入（`action_size=4`）。你可以设置每个输入的最小值（`action_low`）和最大值（`action_high`）。
# - 我们在文件中提供的任务示例将使智能体达到目标位置。我们将目标位置设置为一个变量。
#
# `reset()` 方法将重置模拟器。每当阶段结束时，智能体都将调用此方法。你可以查看下方代码中的例子。
#
# `step()` 方法是最重要的一个方法。它将接收智能体选择的动作 `rotor_speeds`，并准备好下一个状态，同时返回给智能体。接着，你将通过 `get_reward()` 计算奖励值。当超过规定时间，或是四轴飞行器到达模拟器边缘时，这一阶段将视作结束。
#
# 接下来，你将学习如何测试这个任务中智能体的性能。
#
# ## 智能体
#
# `agents/policy_search.py` 文件中提供的智能体示例使用了非常简单的线性策略，将动作向量视作状态向量和矩阵权重的点积直接进行计算。接着，它通过添加一些高斯噪声来随机干扰参数，以产生不同的策略。根据每个阶段获得的平均奖励值（`score`），它将记录迄今为止发现的最佳参数集以及分数的变化状态，并据此调整比例因子来扩大或减少噪音。
#
# 请运行下方代码来查看任务示例中智能体的性能。

# %%
import sys
import pandas as p

# %%
from agents.policy_search import PolicySearch_Agent
from task import Task

labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

num_episodes = 1
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        if i_episode == num_episodes:
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode =    1, score =  -0.440 (best =  -0.440), noise_scale = 0.05

# %%
plot_run(results)

path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=target_pos)

# %% [markdown]
# 这个智能体的性能想必十分糟糕！现在轮到你出场了！
#
# ## 定义任务，设计并训练你的智能体！
#
# 修改 `task.py` 文件来指定你所选择的任务。如果你不确定选择什么任务，你可以教你的四轴飞行器起飞、盘旋、着陆或是达到指定位置。
#
#
# 在指定任务后，使用 `agents/policy_search.py` 中的智能体示例作为模板，来在 `agents/agent.py` 中定义你自己的智能体。你可以随意从智能体示例中借用你需要的元素，包括如何模块化你的代码（使用 `act()`，`learn()` 和 `reset_episode_vars()` 等辅助方法）。
#
# 请注意，你指定的第一个智能体和任务**极有可能**无法顺利进行学习。你将需要改进不同的超参数和奖励函数，直到你能够获得不错的结果。
#
# 在开发智能体的时候，你还需要关注它的性能。参考下方代码，建立一个机制来存储每个阶段的总奖励值。如果阶段奖励值在逐渐上升，说明你的智能体正在学习。

# %%
## TODO: Train your agent here.
from agents.ddpg_agent import DDPG_Agent
from quadcopter_task import Quadcopter_Task
import sys
import pandas as p
import numpy as np
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}
rewards = {"episode":[],"reward":[]}
num_episodes = 600
target_pos = np.array([0., 0., 100.])
init_pos = np.array([0., 0., 10., 0., 0., 0.])
task = Quadcopter_Task(target_pos=target_pos, init_pose=init_pos)
agent = DDPG_Agent(task) 
worst_score = 1000000
best_score = -1000000.
for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    score = 0
    while True:
        action = agent.act(state) 
        #print("action:{}".format(action))
        next_state, reward, done = task.step(action)
        if i_episode == num_episodes:
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(to_write[ii])
        #print("reward:{},done:{}".format(reward,done))
        
        score += reward
        best_score = max(best_score , score)
        worst_score = min(worst_score , score)
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
            print("\rEpisode ={:4d},pose ={:7.3f}, velocity[z]={:7.3f}, score ={:7.3f}(best ={:7.3f},worst ={:7.3f})".format(
               i_episode, task.sim.pose[2],task.sim.v[2],score, best_score, worst_score))
            break
    rewards['episode'].append(i_episode)
    rewards['reward'].append(score)
    sys.stdout.flush()
# Out:
# Using TensorFlow backend.
# sim.init_pos:[ 0.  0. 10.  0.  0.  0.]
# WARNING:tensorflow:From D:\software\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\software\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Episode =   1,pose =  0.000, velocity[z]=-14.158, score =183.952(best =183.952,worst =  6.439)
# Episode =   2,pose =  0.000, velocity[z]=-14.153, score =183.964(best =183.964,worst =  6.439)
# Episode =   3,pose =  0.000, velocity[z]=-14.189, score =183.948(best =183.964,worst =  6.439)
# Episode =   4,pose =  0.000, velocity[z]=-13.379, score =199.465(best =199.465,worst =  6.439)
# Episode =   5,pose =  0.000, velocity[z]=-14.129, score =193.260(best =199.465,worst =  6.439)
# Episode =   6,pose =  0.000, velocity[z]=-13.785, score =164.025(best =199.465,worst =  6.439)
# Episode =   7,pose =  0.000, velocity[z]=-13.831, score =163.911(best =199.465,worst =  6.439)
# Episode =   8,pose =  0.000, velocity[z]=-16.325, score =190.261(best =199.465,worst =  6.439)
# Episode =   9,pose =  0.000, velocity[z]=-15.938, score =170.128(best =199.465,worst =  6.439)
# Episode =  10,pose =  0.000, velocity[z]=-15.431, score =203.090(best =203.090,worst =  6.439)
# Episode =  11,pose =  0.000, velocity[z]=-11.967, score =176.522(best =203.090,worst =  6.439)
# Episode =  12,pose =  0.000, velocity[z]=-17.031, score =177.418(best =203.090,worst =  6.439)
# Episode =  13,pose =  0.000, velocity[z]=-15.006, score =167.385(best =203.090,worst =  6.439)
# Episode =  14,pose =  0.000, velocity[z]=-11.017, score =220.864(best =220.864,worst =  6.439)
# Episode =  15,pose =  0.000, velocity[z]=-12.009, score =157.357(best =220.864,worst =  6.439)
# Episode =  16,pose =  0.000, velocity[z]=-14.479, score =225.304(best =225.304,worst =  6.439)
# Episode =  17,pose =  0.000, velocity[z]=-11.400, score =157.517(best =225.304,worst =  6.439)
# Episode =  18,pose =  0.000, velocity[z]=-15.663, score =235.341(best =235.341,worst =  6.439)
# Episode =  19,pose =  0.000, velocity[z]=-11.124, score =193.136(best =235.341,worst =  6.439)
# Episode =  20,pose =  0.000, velocity[z]=-15.106, score =163.907(best =235.341,worst =  6.439)
# Episode =  21,pose =  0.000, velocity[z]=-13.407, score =180.290(best =235.341,worst =  6.439)
# Episode =  22,pose =  0.000, velocity[z]=-16.765, score =195.850(best =235.341,worst =  6.439)
# Episode =  23,pose =  0.000, velocity[z]=-11.550, score =180.364(best =235.341,worst =  6.439)
# Episode =  24,pose = 17.135, velocity[z]=  6.005, score =558.037(best =558.037,worst =  6.439)
# Episode =  25,pose =  0.000, velocity[z]=-14.240, score =164.022(best =558.037,worst =  6.439)
# Episode =  26,pose =  0.000, velocity[z]=-17.306, score =177.532(best =558.037,worst =  6.439)
# Episode =  27,pose = 33.963, velocity[z]=  8.841, score =560.173(best =560.173,worst =  6.439)
# Episode =  28,pose = 34.998, velocity[z]=  9.184, score =561.020(best =561.020,worst =  6.439)
# Episode =  29,pose = 34.588, velocity[z]=  9.011, score =560.518(best =561.020,worst =  6.439)
# Episode =  30,pose = 35.679, velocity[z]=  9.355, score =562.346(best =562.346,worst =  6.439)
# Episode =  31,pose =  0.000, velocity[z]= -8.917, score =373.171(best =562.346,worst =  6.439)
# Episode =  32,pose =  0.000, velocity[z]=-17.302, score =215.989(best =562.346,worst =  6.439)
# Episode =  33,pose =  0.000, velocity[z]=-12.327, score =205.904(best =562.346,worst =  6.439)
# Episode =  34,pose =  0.000, velocity[z]=-15.496, score =215.851(best =562.346,worst =  6.439)
# Episode =  35,pose =  0.000, velocity[z]=-13.615, score =218.601(best =562.346,worst =  6.439)
# Episode =  36,pose =  0.000, velocity[z]=-14.876, score =205.878(best =562.346,worst =  6.439)
# Episode =  37,pose =  0.000, velocity[z]=-13.736, score =176.703(best =562.346,worst =  6.439)
# Episode =  38,pose =  0.000, velocity[z]=-15.724, score =215.916(best =562.346,worst =  6.439)
# Episode =  39,pose =  0.000, velocity[z]=-15.363, score =215.867(best =562.346,worst =  6.439)
# Episode =  40,pose =  0.000, velocity[z]=-15.562, score =189.504(best =562.346,worst =  6.439)
# Episode =  41,pose =  0.000, velocity[z]=-13.746, score =189.489(best =562.346,worst =  6.439)
# Episode =  42,pose =  0.000, velocity[z]=-15.544, score =215.857(best =562.346,worst =  6.439)
# Episode =  43,pose =  0.000, velocity[z]=-14.203, score =209.482(best =562.346,worst =  6.439)
# Episode =  44,pose =  0.000, velocity[z]=-12.572, score =212.284(best =562.346,worst =  6.439)
# Episode =  45,pose =  0.000, velocity[z]=-14.721, score =209.478(best =562.346,worst =  6.439)
# Episode =  46,pose =  0.000, velocity[z]=-15.415, score =215.876(best =562.346,worst =  6.439)
# Episode =  47,pose =  0.000, velocity[z]=-14.615, score =199.455(best =562.346,worst =  6.439)
# Episode =  48,pose =  0.000, velocity[z]=-14.329, score =195.901(best =562.346,worst =  6.439)
# Episode =  49,pose =  0.000, velocity[z]=-14.104, score =195.928(best =562.346,worst =  6.439)
# Episode =  50,pose =  0.000, velocity[z]=-14.665, score =215.891(best =562.346,worst =  6.439)
# Episode =  51,pose =  0.000, velocity[z]=-14.222, score =195.941(best =562.346,worst =  6.439)
# Episode =  52,pose =  0.000, velocity[z]=-13.748, score =195.924(best =562.346,worst =  6.439)
# Episode =  53,pose =  0.000, velocity[z]=-13.442, score =222.262(best =562.346,worst =  6.439)
# Episode =  54,pose =  0.000, velocity[z]=-14.681, score =205.893(best =562.346,worst =  6.439)
# Episode =  55,pose =  0.000, velocity[z]=-12.550, score =212.280(best =562.346,worst =  6.439)
# Episode =  56,pose =  0.000, velocity[z]=-15.982, score =199.499(best =562.346,worst =  6.439)
# Episode =  57,pose =  0.000, velocity[z]=-15.419, score =189.507(best =562.346,worst =  6.439)
# Episode =  58,pose =  0.000, velocity[z]=-14.520, score =205.913(best =562.346,worst =  6.439)
# Episode =  59,pose =  0.000, velocity[z]=-12.669, score =212.276(best =562.346,worst =  6.439)
# Episode =  60,pose =  0.000, velocity[z]=-14.524, score =205.914(best =562.346,worst =  6.439)
# Episode =  61,pose =  0.000, velocity[z]=-14.224, score =205.912(best =562.346,worst =  6.439)
# Episode =  62,pose =  0.000, velocity[z]=-14.558, score =205.910(best =562.346,worst =  6.439)
# Episode =  63,pose =  0.000, velocity[z]=-14.325, score =195.948(best =562.346,worst =  6.439)
# Episode =  64,pose =  0.000, velocity[z]=-14.535, score =205.912(best =562.346,worst =  6.439)
# Episode =  65,pose =  0.000, velocity[z]=-14.567, score =205.907(best =562.346,worst =  6.439)
# Episode =  66,pose =  0.000, velocity[z]=-14.494, score =209.426(best =562.346,worst =  6.439)
# Episode =  67,pose =  0.000, velocity[z]=-14.486, score =205.915(best =562.346,worst =  6.439)
# Episode =  68,pose =  0.000, velocity[z]=-14.517, score =205.914(best =562.346,worst =  6.439)
# Episode =  69,pose =  0.000, velocity[z]=-14.400, score =205.909(best =562.346,worst =  6.439)
# Episode =  70,pose =  0.000, velocity[z]=-14.524, score =205.911(best =562.346,worst =  6.439)
# Episode =  71,pose =  0.000, velocity[z]=-12.804, score =195.893(best =562.346,worst =  6.439)
# Episode =  72,pose =  0.000, velocity[z]=-14.411, score =195.932(best =562.346,worst =  6.439)
# Episode =  73,pose =  0.000, velocity[z]=-14.407, score =195.929(best =562.346,worst =  6.439)
# Episode =  74,pose =  0.000, velocity[z]=-14.345, score =195.931(best =562.346,worst =  6.439)
# Episode =  75,pose =  0.000, velocity[z]=-14.575, score =205.910(best =562.346,worst =  6.439)
# Episode =  76,pose =  0.000, velocity[z]=-14.536, score =205.909(best =562.346,worst =  6.439)
# Episode =  77,pose =  0.000, velocity[z]=-14.531, score =205.913(best =562.346,worst =  6.439)
# Episode =  78,pose =  0.000, velocity[z]=-14.541, score =205.912(best =562.346,worst =  6.439)
# Episode =  79,pose =  0.000, velocity[z]=-14.127, score =205.900(best =562.346,worst =  6.439)
# Episode =  80,pose =  0.000, velocity[z]=-14.515, score =205.914(best =562.346,worst =  6.439)
# Episode =  81,pose =  0.000, velocity[z]=-16.012, score =222.314(best =562.346,worst =  6.439)
# Episode =  82,pose =  0.000, velocity[z]=-14.109, score =203.046(best =562.346,worst =  6.439)
# Episode =  83,pose =  0.000, velocity[z]=-14.421, score =195.921(best =562.346,worst =  6.439)
# Episode =  84,pose =  0.000, velocity[z]=-16.102, score =215.896(best =562.346,worst =  6.439)
# Episode =  85,pose =  0.000, velocity[z]=-14.389, score =195.932(best =562.346,worst =  6.439)
# Episode =  86,pose =  0.000, velocity[z]=-14.405, score =195.936(best =562.346,worst =  6.439)
# Episode =  87,pose =  0.000, velocity[z]=-14.821, score =195.937(best =562.346,worst =  6.439)
# Episode =  88,pose =  0.000, velocity[z]=-14.918, score =205.887(best =562.346,worst =  6.439)
# Episode =  89,pose =  0.000, velocity[z]=-14.510, score =205.919(best =562.346,worst =  6.439)
# Episode =  90,pose =  0.000, velocity[z]=-14.549, score =205.904(best =562.346,worst =  6.439)
# Episode =  91,pose =  0.000, velocity[z]=-14.516, score =205.918(best =562.346,worst =  6.439)
# Episode =  92,pose =  0.000, velocity[z]=-14.486, score =205.920(best =562.346,worst =  6.439)
# Episode =  93,pose =  0.000, velocity[z]=-14.454, score =193.091(best =562.346,worst =  6.439)
# Episode =  94,pose =  0.000, velocity[z]=-14.566, score =205.910(best =562.346,worst =  6.439)
# Episode =  95,pose =  0.000, velocity[z]=-14.415, score =195.931(best =562.346,worst =  6.439)
# Episode =  96,pose =  0.000, velocity[z]=-14.434, score =195.928(best =562.346,worst =  6.439)
# Episode =  97,pose =  0.000, velocity[z]=-14.559, score =205.910(best =562.346,worst =  6.439)
# Episode =  98,pose =  0.000, velocity[z]=-14.439, score =195.930(best =562.346,worst =  6.439)
# Episode =  99,pose =  0.000, velocity[z]=-16.438, score =215.910(best =562.346,worst =  6.439)
# Episode = 100,pose =  0.000, velocity[z]=-14.381, score =222.329(best =562.346,worst =  6.439)
# Episode = 101,pose =  0.000, velocity[z]=-14.432, score =195.929(best =562.346,worst =  6.439)
# Episode = 102,pose =  0.000, velocity[z]=-13.814, score =212.341(best =562.346,worst =  6.439)
# Episode = 103,pose =  0.000, velocity[z]=-12.589, score =202.313(best =562.346,worst =  6.439)
# Episode = 104,pose =  0.000, velocity[z]=-14.494, score =205.919(best =562.346,worst =  6.439)
# Episode = 105,pose =  0.000, velocity[z]=-12.952, score =222.291(best =562.346,worst =  6.439)
# Episode = 106,pose =  0.000, velocity[z]=-16.076, score =222.306(best =562.346,worst =  6.439)
# Episode = 107,pose =  0.000, velocity[z]=-15.012, score =205.921(best =562.346,worst =  6.439)
# Episode = 108,pose =  0.000, velocity[z]=-15.994, score =222.317(best =562.346,worst =  6.439)
# Episode = 109,pose =  0.000, velocity[z]=-14.587, score =195.930(best =562.346,worst =  6.439)
# Episode = 110,pose =  0.000, velocity[z]=-14.181, score =195.917(best =562.346,worst =  6.439)
# Episode = 111,pose =  0.000, velocity[z]=-14.497, score =205.918(best =562.346,worst =  6.439)
# Episode = 112,pose =  0.000, velocity[z]=-14.602, score =215.897(best =562.346,worst =  6.439)
# Episode = 113,pose =  0.000, velocity[z]=-14.504, score =205.917(best =562.346,worst =  6.439)
# Episode = 114,pose =  0.000, velocity[z]=-14.359, score =199.486(best =562.346,worst =  6.439)
# Episode = 115,pose =  0.000, velocity[z]=-14.379, score =195.939(best =562.346,worst =  6.439)
# Episode = 116,pose =  0.000, velocity[z]=-14.151, score =189.470(best =562.346,worst =  6.439)
# Episode = 117,pose =  0.000, velocity[z]=-15.721, score =218.788(best =562.346,worst =  6.439)
# Episode = 118,pose =  0.000, velocity[z]=-14.434, score =195.930(best =562.346,worst =  6.439)
# Episode = 119,pose =  0.000, velocity[z]=-14.430, score =205.918(best =562.346,worst =  6.439)
# Episode = 120,pose =  0.000, velocity[z]=-15.622, score =228.752(best =562.346,worst =  6.439)
# Episode = 121,pose =  0.000, velocity[z]=-14.639, score =215.897(best =562.346,worst =  6.439)
# Episode = 122,pose =  0.000, velocity[z]=-14.584, score =215.825(best =562.346,worst =  6.439)
# Episode = 123,pose =  0.000, velocity[z]=-14.576, score =205.906(best =562.346,worst =  6.439)
# Episode = 124,pose =  0.000, velocity[z]=-14.345, score =195.938(best =562.346,worst =  6.439)
# Episode = 125,pose =  0.000, velocity[z]=-14.558, score =282.410(best =562.346,worst =  6.439)
# Episode = 126,pose =  0.000, velocity[z]=-11.410, score =301.202(best =562.346,worst =  6.439)
# Episode = 127,pose =  0.000, velocity[z]=-13.139, score =310.631(best =562.346,worst =  6.439)
# Episode = 128,pose =  0.000, velocity[z]=-14.336, score =279.777(best =562.346,worst =  6.439)
# Episode = 129,pose =  0.000, velocity[z]=-13.512, score =273.371(best =562.346,worst =  6.439)
# Episode = 130,pose =  0.000, velocity[z]=-13.432, score =292.590(best =562.346,worst =  6.439)
# Episode = 131,pose =  0.000, velocity[z]=-13.639, score =273.377(best =562.346,worst =  6.439)
# Episode = 132,pose =  0.000, velocity[z]=-13.502, score =273.284(best =562.346,worst =  6.439)
# Episode = 133,pose =  0.000, velocity[z]=-12.947, score =278.568(best =562.346,worst =  6.439)
# Episode = 134,pose =  0.000, velocity[z]=-13.946, score =241.418(best =562.346,worst =  6.439)
# Episode = 135,pose =  0.000, velocity[z]=-13.473, score =227.714(best =562.346,worst =  6.439)
# Episode = 136,pose =  0.000, velocity[z]=-13.532, score =257.124(best =562.346,worst =  6.439)
# Episode = 137,pose =  0.000, velocity[z]=-14.280, score =195.858(best =562.346,worst =  6.439)
# Episode = 138,pose =  0.000, velocity[z]=-12.510, score =247.260(best =562.346,worst =  6.439)
# Episode = 139,pose =  0.000, velocity[z]=-13.087, score =221.357(best =562.346,worst =  6.439)
# Episode = 140,pose =  0.000, velocity[z]=-13.446, score =222.268(best =562.346,worst =  6.439)
# Episode = 141,pose =  0.000, velocity[z]=-14.496, score =205.917(best =562.346,worst =  6.439)
# Episode = 142,pose =  0.000, velocity[z]=-14.476, score =195.924(best =562.346,worst =  6.439)
# Episode = 143,pose =  0.000, velocity[z]=-14.491, score =205.915(best =562.346,worst =  6.439)
# Episode = 144,pose =  0.000, velocity[z]=-14.630, score =215.893(best =562.346,worst =  6.439)
# Episode = 145,pose =  0.000, velocity[z]=-14.443, score =195.922(best =562.346,worst =  6.439)
# Episode = 146,pose =  0.000, velocity[z]=-14.439, score =195.926(best =562.346,worst =  6.439)
# Episode = 147,pose =  0.000, velocity[z]=-14.612, score =215.900(best =562.346,worst =  6.439)
# Episode = 148,pose =  0.000, velocity[z]=-14.558, score =205.913(best =562.346,worst =  6.439)
# Episode = 149,pose =  0.000, velocity[z]=-14.534, score =205.918(best =562.346,worst =  6.439)
# Episode = 150,pose =  0.000, velocity[z]=-14.657, score =215.895(best =562.346,worst =  6.439)
# Episode = 151,pose =  0.000, velocity[z]=-14.503, score =205.916(best =562.346,worst =  6.439)
# Episode = 152,pose =  0.000, velocity[z]=-14.507, score =205.921(best =562.346,worst =  6.439)
# Episode = 153,pose =  0.000, velocity[z]=-14.564, score =205.911(best =562.346,worst =  6.439)
# Episode = 154,pose =  0.000, velocity[z]=-14.433, score =195.931(best =562.346,worst =  6.439)
# Episode = 155,pose =  0.000, velocity[z]=-14.581, score =205.905(best =562.346,worst =  6.439)
# Episode = 156,pose =  0.000, velocity[z]=-14.694, score =215.891(best =562.346,worst =  6.439)
# Episode = 157,pose =  0.000, velocity[z]=-13.571, score =189.523(best =562.346,worst =  6.439)
# Episode = 158,pose =  0.000, velocity[z]=-14.557, score =205.911(best =562.346,worst =  6.439)
# Episode = 159,pose =  0.000, velocity[z]=-14.482, score =205.921(best =562.346,worst =  6.439)
# Episode = 160,pose =  0.000, velocity[z]=-14.509, score =205.918(best =562.346,worst =  6.439)
# Episode = 161,pose =  0.000, velocity[z]=-14.344, score =195.943(best =562.346,worst =  6.439)
# Episode = 162,pose =  0.000, velocity[z]=-14.498, score =205.917(best =562.346,worst =  6.439)
# Episode = 163,pose =  0.000, velocity[z]=-14.372, score =195.937(best =562.346,worst =  6.439)
# Episode = 164,pose =  0.000, velocity[z]=-14.599, score =205.906(best =562.346,worst =  6.439)
# Episode = 165,pose =  0.000, velocity[z]=-14.496, score =205.920(best =562.346,worst =  6.439)
# Episode = 166,pose =  0.000, velocity[z]=-14.534, score =205.917(best =562.346,worst =  6.439)
# Episode = 167,pose =  0.000, velocity[z]=-14.487, score =205.922(best =562.346,worst =  6.439)
# Episode = 168,pose =  0.000, velocity[z]=-14.585, score =205.913(best =562.346,worst =  6.439)
# Episode = 169,pose =  0.000, velocity[z]=-14.422, score =205.920(best =562.346,worst =  6.439)
# Episode = 170,pose =  0.000, velocity[z]=-14.338, score =195.939(best =562.346,worst =  6.439)
# Episode = 171,pose =  0.000, velocity[z]=-14.493, score =205.919(best =562.346,worst =  6.439)
# Episode = 172,pose =  0.000, velocity[z]=-14.583, score =205.906(best =562.346,worst =  6.439)
# Episode = 173,pose =  0.000, velocity[z]=-14.438, score =195.935(best =562.346,worst =  6.439)
# Episode = 174,pose =  0.000, velocity[z]=-14.582, score =205.908(best =562.346,worst =  6.439)
# Episode = 175,pose =  0.000, velocity[z]=-14.430, score =205.923(best =562.346,worst =  6.439)
# Episode = 176,pose =  0.000, velocity[z]=-14.476, score =205.923(best =562.346,worst =  6.439)
# Episode = 177,pose =  0.000, velocity[z]=-14.382, score =195.937(best =562.346,worst =  6.439)
# Episode = 178,pose =  0.000, velocity[z]=-14.470, score =205.923(best =562.346,worst =  6.439)
# Episode = 179,pose =  0.000, velocity[z]=-14.526, score =205.917(best =562.346,worst =  6.439)
# Episode = 180,pose =  0.000, velocity[z]=-14.512, score =205.918(best =562.346,worst =  6.439)
# Episode = 181,pose =  0.000, velocity[z]=-14.534, score =205.912(best =562.346,worst =  6.439)
# Episode = 182,pose =  0.000, velocity[z]=-14.477, score =205.918(best =562.346,worst =  6.439)
# Episode = 183,pose =  0.000, velocity[z]=-14.383, score =195.939(best =562.346,worst =  6.439)
# Episode = 184,pose =  0.000, velocity[z]=-14.547, score =205.910(best =562.346,worst =  6.439)
# Episode = 185,pose =  0.000, velocity[z]=-16.057, score =222.310(best =562.346,worst =  6.439)
# Episode = 186,pose =  0.000, velocity[z]=-14.478, score =205.925(best =562.346,worst =  6.439)
# Episode = 187,pose =  0.000, velocity[z]=-14.490, score =205.920(best =562.346,worst =  6.439)
# Episode = 188,pose =  0.000, velocity[z]=-14.470, score =195.925(best =562.346,worst =  6.439)
# Episode = 189,pose =  0.000, velocity[z]=-14.597, score =205.903(best =562.346,worst =  6.439)
# Episode = 190,pose =  0.000, velocity[z]=-14.461, score =195.924(best =562.346,worst =  6.439)
# Episode = 191,pose =  0.000, velocity[z]=-14.350, score =195.939(best =562.346,worst =  6.439)
# Episode = 192,pose =  0.000, velocity[z]=-14.519, score =205.914(best =562.346,worst =  6.439)
# Episode = 193,pose =  0.000, velocity[z]=-14.524, score =205.914(best =562.346,worst =  6.439)
# Episode = 194,pose =  0.000, velocity[z]=-14.528, score =205.911(best =562.346,worst =  6.439)
# Episode = 195,pose =  0.000, velocity[z]=-14.508, score =205.917(best =562.346,worst =  6.439)
# Episode = 196,pose =  0.000, velocity[z]=-14.639, score =215.898(best =562.346,worst =  6.439)
# Episode = 197,pose =  0.000, velocity[z]=-14.559, score =205.910(best =562.346,worst =  6.439)
# Episode = 198,pose =  0.000, velocity[z]=-15.974, score =222.317(best =562.346,worst =  6.439)
# Episode = 199,pose =  0.000, velocity[z]=-14.383, score =195.934(best =562.346,worst =  6.439)
# Episode = 200,pose =  0.000, velocity[z]=-14.366, score =195.934(best =562.346,worst =  6.439)
# Episode = 201,pose =  0.000, velocity[z]=-14.354, score =195.939(best =562.346,worst =  6.439)
# Episode = 202,pose =  0.000, velocity[z]=-14.384, score =195.930(best =562.346,worst =  6.439)
# Episode = 203,pose =  0.000, velocity[z]=-14.705, score =215.892(best =562.346,worst =  6.439)
# Episode = 204,pose =  0.000, velocity[z]=-16.030, score =222.308(best =562.346,worst =  6.439)
# Episode = 205,pose =  0.000, velocity[z]=-14.542, score =205.914(best =562.346,worst =  6.439)
# Episode = 206,pose =  0.000, velocity[z]=-14.433, score =195.926(best =562.346,worst =  6.439)
# Episode = 207,pose =  0.000, velocity[z]=-14.533, score =205.917(best =562.346,worst =  6.439)
# Episode = 208,pose =  0.000, velocity[z]=-14.544, score =205.915(best =562.346,worst =  6.439)
# Episode = 209,pose =  0.000, velocity[z]=-14.643, score =215.896(best =562.346,worst =  6.439)
# Episode = 210,pose =  0.000, velocity[z]=-14.701, score =215.889(best =562.346,worst =  6.439)
# Episode = 211,pose =  0.000, velocity[z]=-14.424, score =195.928(best =562.346,worst =  6.439)
# Episode = 212,pose =  0.000, velocity[z]=-14.382, score =195.939(best =562.346,worst =  6.439)
# Episode = 213,pose =  0.000, velocity[z]=-14.536, score =205.907(best =562.346,worst =  6.439)
# Episode = 214,pose =  0.000, velocity[z]=-14.539, score =205.909(best =562.346,worst =  6.439)
# Episode = 215,pose =  0.000, velocity[z]=-14.596, score =205.902(best =562.346,worst =  6.439)
# Episode = 216,pose =  0.000, velocity[z]=-14.483, score =205.919(best =562.346,worst =  6.439)
# Episode = 217,pose =  0.000, velocity[z]=-14.400, score =195.935(best =562.346,worst =  6.439)
# Episode = 218,pose =  0.000, velocity[z]=-14.471, score =205.919(best =562.346,worst =  6.439)
# Episode = 219,pose =  0.000, velocity[z]=-14.466, score =205.922(best =562.346,worst =  6.439)
# Episode = 220,pose =  0.000, velocity[z]=-14.546, score =205.913(best =562.346,worst =  6.439)
# Episode = 221,pose =  0.000, velocity[z]=-14.566, score =205.907(best =562.346,worst =  6.439)
# Episode = 222,pose =  0.000, velocity[z]=-14.535, score =205.914(best =562.346,worst =  6.439)
# Episode = 223,pose =  0.000, velocity[z]=-14.593, score =205.904(best =562.346,worst =  6.439)
# Episode = 224,pose =  0.000, velocity[z]=-14.436, score =205.924(best =562.346,worst =  6.439)
# Episode = 225,pose =  0.000, velocity[z]=-14.416, score =195.932(best =562.346,worst =  6.439)
# Episode = 226,pose =  0.000, velocity[z]=-14.583, score =205.906(best =562.346,worst =  6.439)
# Episode = 227,pose =  0.000, velocity[z]=-14.427, score =195.932(best =562.346,worst =  6.439)
# Episode = 228,pose =  0.000, velocity[z]=-14.421, score =195.935(best =562.346,worst =  6.439)
# Episode = 229,pose =  0.000, velocity[z]=-14.436, score =195.926(best =562.346,worst =  6.439)
# Episode = 230,pose =  0.000, velocity[z]=-14.454, score =195.927(best =562.346,worst =  6.439)
# Episode = 231,pose =  0.000, velocity[z]=-14.323, score =195.947(best =562.346,worst =  6.439)
# Episode = 232,pose =  0.000, velocity[z]=-14.482, score =205.921(best =562.346,worst =  6.439)
# Episode = 233,pose =  0.000, velocity[z]=-14.398, score =195.937(best =562.346,worst =  6.439)
# Episode = 234,pose =  0.000, velocity[z]=-14.524, score =205.920(best =562.346,worst =  6.439)
# Episode = 235,pose =  0.000, velocity[z]=-14.445, score =205.921(best =562.346,worst =  6.439)
# Episode = 236,pose =  0.000, velocity[z]=-14.532, score =205.912(best =562.346,worst =  6.439)
# Episode = 237,pose =  0.000, velocity[z]=-14.548, score =205.907(best =562.346,worst =  6.439)
# Episode = 238,pose =  0.000, velocity[z]=-14.701, score =215.890(best =562.346,worst =  6.439)
# Episode = 239,pose =  0.000, velocity[z]=-14.646, score =215.900(best =562.346,worst =  6.439)
# Episode = 240,pose =  0.000, velocity[z]=-14.576, score =205.908(best =562.346,worst =  6.439)
# Episode = 241,pose =  0.000, velocity[z]=-14.372, score =195.938(best =562.346,worst =  6.439)
# Episode = 242,pose =  0.000, velocity[z]=-14.532, score =205.915(best =562.346,worst =  6.439)
# Episode = 243,pose =  0.000, velocity[z]=-14.502, score =205.921(best =562.346,worst =  6.439)
# Episode = 244,pose =  0.000, velocity[z]=-14.557, score =205.904(best =562.346,worst =  6.439)
# Episode = 245,pose =  0.000, velocity[z]=-14.430, score =195.929(best =562.346,worst =  6.439)
# Episode = 246,pose =  0.000, velocity[z]=-14.612, score =205.901(best =562.346,worst =  6.439)
# Episode = 247,pose =  0.000, velocity[z]=-14.424, score =195.931(best =562.346,worst =  6.439)
# Episode = 248,pose =  0.000, velocity[z]=-14.479, score =205.919(best =562.346,worst =  6.439)
# Episode = 249,pose =  0.000, velocity[z]=-14.366, score =195.935(best =562.346,worst =  6.439)
# Episode = 250,pose =  0.000, velocity[z]=-14.440, score =195.927(best =562.346,worst =  6.439)
# Episode = 251,pose =  0.000, velocity[z]=-14.633, score =215.898(best =562.346,worst =  6.439)
# Episode = 252,pose =  0.000, velocity[z]=-14.442, score =195.929(best =562.346,worst =  6.439)
# Episode = 253,pose =  0.000, velocity[z]=-14.508, score =205.916(best =562.346,worst =  6.439)
# Episode = 254,pose =  0.000, velocity[z]=-14.452, score =195.924(best =562.346,worst =  6.439)
# Episode = 255,pose =  0.000, velocity[z]=-14.731, score =215.892(best =562.346,worst =  6.439)
# Episode = 256,pose =  0.000, velocity[z]=-14.537, score =205.913(best =562.346,worst =  6.439)
# Episode = 257,pose =  0.000, velocity[z]=-14.447, score =195.925(best =562.346,worst =  6.439)
# Episode = 258,pose =  0.000, velocity[z]=-14.422, score =195.933(best =562.346,worst =  6.439)
# Episode = 259,pose =  0.000, velocity[z]=-14.587, score =205.910(best =562.346,worst =  6.439)
# Episode = 260,pose =  0.000, velocity[z]=-14.387, score =195.936(best =562.346,worst =  6.439)
# Episode = 261,pose =  0.000, velocity[z]=-14.358, score =195.940(best =562.346,worst =  6.439)
# Episode = 262,pose =  0.000, velocity[z]=-14.679, score =215.894(best =562.346,worst =  6.439)
# Episode = 263,pose =  0.000, velocity[z]=-14.698, score =215.888(best =562.346,worst =  6.439)
# Episode = 264,pose =  0.000, velocity[z]=-14.540, score =205.906(best =562.346,worst =  6.439)
# Episode = 265,pose =  0.000, velocity[z]=-14.432, score =195.929(best =562.346,worst =  6.439)
# Episode = 266,pose =  0.000, velocity[z]=-14.642, score =215.900(best =562.346,worst =  6.439)
# Episode = 267,pose =  0.000, velocity[z]=-13.649, score =199.227(best =562.346,worst =  6.439)
# Episode = 268,pose = 35.890, velocity[z]=  9.363, score =562.244(best =562.346,worst =  6.439)
# Episode = 269,pose = 35.599, velocity[z]=  9.353, score =561.782(best =562.346,worst =  6.439)
# Episode = 270,pose = 35.760, velocity[z]=  9.352, score =562.454(best =562.454,worst =  6.439)
# Episode = 271,pose = 35.646, velocity[z]=  9.345, score =562.264(best =562.454,worst =  6.439)
# Episode = 272,pose = 35.644, velocity[z]=  9.356, score =562.475(best =562.475,worst =  6.439)
# Episode = 273,pose = 35.408, velocity[z]=  9.221, score =562.272(best =562.475,worst =  6.439)
# Episode = 274,pose = 35.383, velocity[z]=  9.133, score =561.395(best =562.475,worst =  6.439)
# Episode = 275,pose = 35.438, velocity[z]=  9.338, score =561.892(best =562.475,worst =  6.439)
# Episode = 276,pose = 35.764, velocity[z]=  9.348, score =561.505(best =562.475,worst =  6.439)
# Episode = 277,pose = 35.784, velocity[z]=  9.352, score =562.335(best =562.475,worst =  6.439)
# Episode = 278,pose = 35.629, velocity[z]=  9.365, score =561.790(best =562.475,worst =  6.439)
# Episode = 279,pose = 35.287, velocity[z]=  9.202, score =562.282(best =562.475,worst =  6.439)
# Episode = 280,pose = 35.668, velocity[z]=  9.340, score =562.476(best =562.476,worst =  6.439)
# Episode = 281,pose = 34.906, velocity[z]=  9.095, score =560.809(best =562.476,worst =  6.439)
# Episode = 282,pose = 35.772, velocity[z]=  9.379, score =561.909(best =562.476,worst =  6.439)
# Episode = 283,pose = 35.666, velocity[z]=  9.350, score =562.375(best =562.476,worst =  6.439)
# Episode = 284,pose = 35.437, velocity[z]=  9.328, score =561.332(best =562.476,worst =  6.439)
# Episode = 285,pose = 35.496, velocity[z]=  9.335, score =562.447(best =562.476,worst =  6.439)
# Episode = 286,pose = 35.184, velocity[z]=  9.029, score =560.997(best =562.476,worst =  6.439)
# Episode = 287,pose = 35.363, velocity[z]=  9.222, score =562.109(best =562.476,worst =  6.439)
# Episode = 288,pose = 35.648, velocity[z]=  9.319, score =562.597(best =562.597,worst =  6.439)
# Episode = 289,pose = 35.511, velocity[z]=  9.277, score =562.071(best =562.597,worst =  6.439)
# Episode = 290,pose = 34.626, velocity[z]=  8.788, score =561.340(best =562.597,worst =  6.439)
# Episode = 291,pose = 35.472, velocity[z]=  9.310, score =562.462(best =562.597,worst =  6.439)
# Episode = 292,pose = 35.467, velocity[z]=  9.286, score =562.464(best =562.597,worst =  6.439)
# Episode = 293,pose = 35.467, velocity[z]=  9.232, score =562.364(best =562.597,worst =  6.439)
# Episode = 294,pose = 35.108, velocity[z]=  9.077, score =561.817(best =562.597,worst =  6.439)
# Episode = 295,pose = 35.254, velocity[z]=  9.120, score =560.891(best =562.597,worst =  6.439)
# Episode = 296,pose = 35.523, velocity[z]=  9.256, score =562.356(best =562.597,worst =  6.439)
# Episode = 297,pose = 35.812, velocity[z]=  9.391, score =561.761(best =562.597,worst =  6.439)
# Episode = 298,pose = 35.241, velocity[z]=  9.241, score =562.204(best =562.597,worst =  6.439)
# Episode = 299,pose = 35.170, velocity[z]=  9.122, score =561.007(best =562.597,worst =  6.439)
# Episode = 300,pose = 35.390, velocity[z]=  9.211, score =562.320(best =562.597,worst =  6.439)
# Episode = 301,pose = 35.718, velocity[z]=  9.355, score =562.028(best =562.597,worst =  6.439)
# Episode = 302,pose = 35.539, velocity[z]=  9.288, score =562.607(best =562.607,worst =  6.439)
# Episode = 303,pose = 35.564, velocity[z]=  9.285, score =561.682(best =562.607,worst =  6.439)
# Episode = 304,pose = 35.600, velocity[z]=  9.342, score =562.385(best =562.607,worst =  6.439)
# Episode = 305,pose = 35.475, velocity[z]=  9.249, score =561.524(best =562.607,worst =  6.439)
# Episode = 306,pose = 35.461, velocity[z]=  9.312, score =562.549(best =562.607,worst =  6.439)
# Episode = 307,pose = 35.182, velocity[z]=  9.177, score =561.520(best =562.607,worst =  6.439)
# Episode = 308,pose = 35.466, velocity[z]=  9.340, score =561.739(best =562.607,worst =  6.439)
# Episode = 309,pose = 35.552, velocity[z]=  9.322, score =561.775(best =562.607,worst =  6.439)
# Episode = 310,pose =  0.000, velocity[z]=-15.106, score =170.270(best =562.607,worst =  6.439)
# Episode = 311,pose =  0.000, velocity[z]=-16.392, score =189.500(best =562.607,worst =  6.439)
# Episode = 312,pose =  0.000, velocity[z]=-16.310, score =215.907(best =562.607,worst =  6.439)
# Episode = 313,pose =  0.000, velocity[z]=-14.866, score =195.939(best =562.607,worst =  6.439)
# Episode = 314,pose =  0.000, velocity[z]=-16.333, score =199.483(best =562.607,worst =  6.439)
# Episode = 315,pose =  0.000, velocity[z]=-16.420, score =199.498(best =562.607,worst =  6.439)
# Episode = 316,pose =  0.000, velocity[z]=-16.293, score =199.472(best =562.607,worst =  6.439)
# Episode = 317,pose =  0.000, velocity[z]=-16.287, score =189.495(best =562.607,worst =  6.439)
# Episode = 318,pose =  0.000, velocity[z]=-15.621, score =215.894(best =562.607,worst =  6.439)
# Episode = 319,pose =  0.000, velocity[z]=-15.621, score =205.915(best =562.607,worst =  6.439)
# Episode = 320,pose =  0.000, velocity[z]=-16.023, score =215.893(best =562.607,worst =  6.439)
# Episode = 321,pose =  0.000, velocity[z]=-15.616, score =205.918(best =562.607,worst =  6.439)
# Episode = 322,pose =  0.000, velocity[z]=-14.139, score =218.690(best =562.607,worst =  6.439)
# Episode = 323,pose =  0.000, velocity[z]=-15.698, score =215.893(best =562.607,worst =  6.439)
# Episode = 324,pose =  0.000, velocity[z]=-14.717, score =205.916(best =562.607,worst =  6.439)
# Episode = 325,pose =  0.000, velocity[z]=-15.526, score =205.936(best =562.607,worst =  6.439)
# Episode = 326,pose =  0.000, velocity[z]=-15.184, score =205.910(best =562.607,worst =  6.439)
# Episode = 327,pose =  0.000, velocity[z]=-14.660, score =218.675(best =562.607,worst =  6.439)
# Episode = 328,pose =  0.000, velocity[z]=-12.929, score =228.646(best =562.607,worst =  6.439)
# Episode = 329,pose =  0.000, velocity[z]=-13.949, score =202.307(best =562.607,worst =  6.439)
# Episode = 330,pose =  0.000, velocity[z]=-14.744, score =205.872(best =562.607,worst =  6.439)
# Episode = 331,pose =  0.000, velocity[z]=-13.373, score =241.383(best =562.607,worst =  6.439)
# Episode = 332,pose =  0.000, velocity[z]=-14.437, score =222.281(best =562.607,worst =  6.439)
# Episode = 333,pose =  0.000, velocity[z]=-14.951, score =186.622(best =562.607,worst =  6.439)
# Episode = 334,pose =  0.000, velocity[z]=-14.134, score =157.405(best =562.607,worst =  6.439)
# Episode = 335,pose =  0.000, velocity[z]=-13.496, score =183.059(best =562.607,worst =  6.439)
# Episode = 336,pose =  0.000, velocity[z]=-13.495, score =190.243(best =562.607,worst =  6.439)
# Episode = 337,pose =  0.000, velocity[z]=-14.444, score =151.022(best =562.607,worst =  6.439)
# Episode = 338,pose =  0.000, velocity[z]=-14.058, score =163.830(best =562.607,worst =  6.439)
# Episode = 339,pose =  0.000, velocity[z]=-15.245, score =161.079(best =562.607,worst =  6.439)
# Episode = 340,pose =  0.000, velocity[z]=-10.740, score =227.539(best =562.607,worst =  6.439)
# Episode = 341,pose =  0.000, velocity[z]=-14.714, score =167.498(best =562.607,worst =  6.439)
# Episode = 342,pose =  0.000, velocity[z]=-14.400, score =157.520(best =562.607,worst =  6.439)
# Episode = 343,pose =  0.000, velocity[z]=-11.801, score =193.220(best =562.607,worst =  6.439)
# Episode = 344,pose =  0.000, velocity[z]=-13.339, score =196.634(best =562.607,worst =  6.439)
# Episode = 345,pose =  0.000, velocity[z]=-11.095, score =176.745(best =562.607,worst =  6.439)
# Episode = 346,pose =  0.000, velocity[z]=-15.443, score =176.635(best =562.607,worst =  6.439)
# Episode = 347,pose =  0.000, velocity[z]=-13.588, score =244.454(best =562.607,worst =  6.439)
# Episode = 348,pose =  0.000, velocity[z]=-13.980, score =203.067(best =562.607,worst =  6.439)
# Episode = 349,pose =  0.000, velocity[z]=-12.331, score =154.609(best =562.607,worst =  6.439)
# Episode = 350,pose =  0.000, velocity[z]=-14.269, score =196.683(best =562.607,worst =  6.439)
# Episode = 351,pose =  0.000, velocity[z]=-15.911, score =190.280(best =562.607,worst =  6.439)
# Episode = 352,pose =  0.000, velocity[z]=-14.155, score =183.186(best =562.607,worst =  6.439)
# Episode = 353,pose =  0.000, velocity[z]=-16.095, score =203.173(best =562.607,worst =  6.439)
# Episode = 354,pose =  0.000, velocity[z]=-12.774, score =225.013(best =562.607,worst =  6.439)
# Episode = 355,pose =  0.000, velocity[z]=-13.577, score =205.914(best =562.607,worst =  6.439)
# Episode = 356,pose =  0.000, velocity[z]=-15.061, score =222.266(best =562.607,worst =  6.439)
# Episode = 357,pose =  0.000, velocity[z]=-14.500, score =205.906(best =562.607,worst =  6.439)
# Episode = 358,pose =  0.000, velocity[z]=-14.826, score =205.911(best =562.607,worst =  6.439)
# Episode = 359,pose =  0.000, velocity[z]=-14.573, score =205.913(best =562.607,worst =  6.439)
# Episode = 360,pose =  0.000, velocity[z]=-14.577, score =205.904(best =562.607,worst =  6.439)
# Episode = 361,pose =  0.000, velocity[z]=-14.489, score =195.930(best =562.607,worst =  6.439)
# Episode = 362,pose =  0.000, velocity[z]=-14.572, score =205.914(best =562.607,worst =  6.439)
# Episode = 363,pose =  0.000, velocity[z]=-14.611, score =205.910(best =562.607,worst =  6.439)
# Episode = 364,pose =  0.000, velocity[z]=-17.394, score =199.535(best =562.607,worst =  6.439)
# Episode = 365,pose =  0.000, velocity[z]=-14.741, score =215.887(best =562.607,worst =  6.439)
# Episode = 366,pose =  0.000, velocity[z]=-14.648, score =215.903(best =562.607,worst =  6.439)
# Episode = 367,pose =  0.000, velocity[z]=-14.629, score =205.922(best =562.607,worst =  6.439)
# Episode = 368,pose =  0.000, velocity[z]=-14.550, score =205.917(best =562.607,worst =  6.439)
# Episode = 369,pose =  0.000, velocity[z]=-14.532, score =205.912(best =562.607,worst =  6.439)
# Episode = 370,pose =  0.000, velocity[z]=-14.539, score =195.930(best =562.607,worst =  6.439)
# Episode = 371,pose =  0.000, velocity[z]=-14.630, score =215.898(best =562.607,worst =  6.439)
# Episode = 372,pose =  0.000, velocity[z]=-14.560, score =205.915(best =562.607,worst =  6.439)
# Episode = 373,pose =  0.000, velocity[z]=-15.215, score =205.928(best =562.607,worst =  6.439)
# Episode = 374,pose =  0.000, velocity[z]=-14.665, score =205.904(best =562.607,worst =  6.439)
# Episode = 375,pose =  0.000, velocity[z]=-14.700, score =215.896(best =562.607,worst =  6.439)
# Episode = 376,pose =  0.000, velocity[z]=-14.562, score =195.927(best =562.607,worst =  6.439)
# Episode = 377,pose =  0.000, velocity[z]=-14.439, score =195.935(best =562.607,worst =  6.439)
# Episode = 378,pose =  0.000, velocity[z]=-14.383, score =195.939(best =562.607,worst =  6.439)
# Episode = 379,pose =  0.000, velocity[z]=-14.607, score =205.902(best =562.607,worst =  6.439)
# Episode = 380,pose =  0.000, velocity[z]=-14.424, score =195.936(best =562.607,worst =  6.439)
# Episode = 381,pose =  0.000, velocity[z]=-14.531, score =205.913(best =562.607,worst =  6.439)
# Episode = 382,pose =  0.000, velocity[z]=-16.386, score =189.557(best =562.607,worst =  6.439)
# Episode = 383,pose =  0.000, velocity[z]=-14.530, score =205.915(best =562.607,worst =  6.439)
# Episode = 384,pose =  0.000, velocity[z]=-14.501, score =205.914(best =562.607,worst =  6.439)
# Episode = 385,pose =  0.000, velocity[z]=-14.485, score =205.920(best =562.607,worst =  6.439)
# Episode = 386,pose =  0.000, velocity[z]=-14.546, score =205.915(best =562.607,worst =  6.439)
# Episode = 387,pose =  0.000, velocity[z]=-14.366, score =195.939(best =562.607,worst =  6.439)
# Episode = 388,pose =  0.000, velocity[z]=-14.469, score =205.923(best =562.607,worst =  6.439)
# Episode = 389,pose =  0.000, velocity[z]=-14.732, score =205.919(best =562.607,worst =  6.439)
# Episode = 390,pose =  0.000, velocity[z]=-14.438, score =195.927(best =562.607,worst =  6.439)
# Episode = 391,pose =  0.000, velocity[z]=-14.453, score =195.931(best =562.607,worst =  6.439)
# Episode = 392,pose =  0.000, velocity[z]=-14.492, score =205.919(best =562.607,worst =  6.439)
# Episode = 393,pose =  0.000, velocity[z]=-15.086, score =215.893(best =562.607,worst =  6.439)
# Episode = 394,pose =  0.000, velocity[z]=-13.761, score =205.892(best =562.607,worst =  6.439)
# Episode = 395,pose =  0.000, velocity[z]=-14.524, score =205.917(best =562.607,worst =  6.439)
# Episode = 396,pose =  0.000, velocity[z]=-14.594, score =205.908(best =562.607,worst =  6.439)
# Episode = 397,pose =  0.000, velocity[z]=-14.510, score =205.915(best =562.607,worst =  6.439)
# Episode = 398,pose =  0.000, velocity[z]=-16.062, score =215.908(best =562.607,worst =  6.439)
# Episode = 399,pose =  0.000, velocity[z]=-14.785, score =205.912(best =562.607,worst =  6.439)
# Episode = 400,pose =  0.000, velocity[z]=-16.382, score =215.899(best =562.607,worst =  6.439)
# Episode = 401,pose =  0.000, velocity[z]=-14.490, score =195.924(best =562.607,worst =  6.439)
# Episode = 402,pose =  0.000, velocity[z]=-14.193, score =218.569(best =562.607,worst =  6.439)
# Episode = 403,pose =  0.000, velocity[z]=-15.279, score =205.908(best =562.607,worst =  6.439)
# Episode = 404,pose =  0.000, velocity[z]=-14.207, score =212.309(best =562.607,worst =  6.439)
# Episode = 405,pose =  0.000, velocity[z]=-15.562, score =215.883(best =562.607,worst =  6.439)
# Episode = 406,pose =  0.000, velocity[z]=-15.169, score =215.894(best =562.607,worst =  6.439)
# Episode = 407,pose =  0.000, velocity[z]=-14.514, score =205.920(best =562.607,worst =  6.439)
# Episode = 408,pose =  0.000, velocity[z]=-16.114, score =222.314(best =562.607,worst =  6.439)
# Episode = 409,pose =  0.000, velocity[z]=-15.163, score =205.923(best =562.607,worst =  6.439)
# Episode = 410,pose =  0.000, velocity[z]=-14.750, score =215.885(best =562.607,worst =  6.439)
# Episode = 411,pose =  0.000, velocity[z]=-14.544, score =205.920(best =562.607,worst =  6.439)
# Episode = 412,pose =  0.000, velocity[z]=-15.787, score =215.869(best =562.607,worst =  6.439)
# Episode = 413,pose =  0.000, velocity[z]=-14.584, score =205.906(best =562.607,worst =  6.439)
# Episode = 414,pose =  0.000, velocity[z]=-15.160, score =215.891(best =562.607,worst =  6.439)
# Episode = 415,pose =  0.000, velocity[z]=-14.389, score =195.938(best =562.607,worst =  6.439)
# Episode = 416,pose =  0.000, velocity[z]=-14.436, score =195.929(best =562.607,worst =  6.439)
# Episode = 417,pose =  0.000, velocity[z]=-14.483, score =205.919(best =562.607,worst =  6.439)
# Episode = 418,pose =  0.000, velocity[z]=-14.530, score =205.914(best =562.607,worst =  6.439)
# Episode = 419,pose =  0.000, velocity[z]=-14.450, score =195.928(best =562.607,worst =  6.439)
# Episode = 420,pose =  0.000, velocity[z]=-14.360, score =195.938(best =562.607,worst =  6.439)
# Episode = 421,pose =  0.000, velocity[z]=-14.514, score =205.914(best =562.607,worst =  6.439)
# Episode = 422,pose =  0.000, velocity[z]=-14.423, score =195.932(best =562.607,worst =  6.439)
# Episode = 423,pose =  0.000, velocity[z]=-14.626, score =215.899(best =562.607,worst =  6.439)
# Episode = 424,pose =  0.000, velocity[z]=-14.457, score =205.922(best =562.607,worst =  6.439)
# Episode = 425,pose =  0.000, velocity[z]=-14.460, score =205.919(best =562.607,worst =  6.439)
# Episode = 426,pose =  0.000, velocity[z]=-14.665, score =215.894(best =562.607,worst =  6.439)
# Episode = 427,pose =  0.000, velocity[z]=-14.534, score =205.916(best =562.607,worst =  6.439)
# Episode = 428,pose =  0.000, velocity[z]=-14.456, score =195.928(best =562.607,worst =  6.439)
# Episode = 429,pose =  0.000, velocity[z]=-14.509, score =205.915(best =562.607,worst =  6.439)
# Episode = 430,pose =  0.000, velocity[z]=-14.431, score =195.927(best =562.607,worst =  6.439)
# Episode = 431,pose =  0.000, velocity[z]=-14.493, score =205.918(best =562.607,worst =  6.439)
# Episode = 432,pose =  0.000, velocity[z]=-14.455, score =205.920(best =562.607,worst =  6.439)
# Episode = 433,pose =  0.000, velocity[z]=-14.455, score =195.924(best =562.607,worst =  6.439)
# Episode = 434,pose =  0.000, velocity[z]=-14.477, score =205.919(best =562.607,worst =  6.439)
# Episode = 435,pose =  0.000, velocity[z]=-15.988, score =222.316(best =562.607,worst =  6.439)
# Episode = 436,pose =  0.000, velocity[z]=-14.669, score =215.892(best =562.607,worst =  6.439)
# Episode = 437,pose =  0.000, velocity[z]=-15.976, score =222.316(best =562.607,worst =  6.439)
# Episode = 438,pose =  0.000, velocity[z]=-14.546, score =205.909(best =562.607,worst =  6.439)
# Episode = 439,pose =  0.000, velocity[z]=-14.474, score =205.921(best =562.607,worst =  6.439)
# Episode = 440,pose =  0.000, velocity[z]=-14.467, score =205.917(best =562.607,worst =  6.439)
# Episode = 441,pose =  0.000, velocity[z]=-14.530, score =205.912(best =562.607,worst =  6.439)
# Episode = 442,pose =  0.000, velocity[z]=-14.402, score =195.928(best =562.607,worst =  6.439)
# Episode = 443,pose =  0.000, velocity[z]=-14.520, score =205.913(best =562.607,worst =  6.439)
# Episode = 444,pose =  0.000, velocity[z]=-14.657, score =215.897(best =562.607,worst =  6.439)
# Episode = 445,pose =  0.000, velocity[z]=-14.606, score =205.904(best =562.607,worst =  6.439)
# Episode = 446,pose =  0.000, velocity[z]=-14.590, score =205.903(best =562.607,worst =  6.439)
# Episode = 447,pose =  0.000, velocity[z]=-14.567, score =205.906(best =562.607,worst =  6.439)
# Episode = 448,pose =  0.000, velocity[z]=-14.532, score =205.912(best =562.607,worst =  6.439)
# Episode = 449,pose =  0.000, velocity[z]=-16.052, score =222.308(best =562.607,worst =  6.439)
# Episode = 450,pose =  0.000, velocity[z]=-14.552, score =205.909(best =562.607,worst =  6.439)
# Episode = 451,pose =  0.000, velocity[z]=-14.606, score =205.901(best =562.607,worst =  6.439)
# Episode = 452,pose =  0.000, velocity[z]=-14.461, score =195.926(best =562.607,worst =  6.439)
# Episode = 453,pose =  0.000, velocity[z]=-14.468, score =205.922(best =562.607,worst =  6.439)
# Episode = 454,pose =  0.000, velocity[z]=-14.486, score =205.923(best =562.607,worst =  6.439)
# Episode = 455,pose =  0.000, velocity[z]=-14.444, score =205.917(best =562.607,worst =  6.439)
# Episode = 456,pose =  0.000, velocity[z]=-14.580, score =205.905(best =562.607,worst =  6.439)
# Episode = 457,pose =  0.000, velocity[z]=-14.441, score =195.929(best =562.607,worst =  6.439)
# Episode = 458,pose =  0.000, velocity[z]=-14.341, score =195.946(best =562.607,worst =  6.439)
# Episode = 459,pose =  0.000, velocity[z]=-14.583, score =205.905(best =562.607,worst =  6.439)
# Episode = 460,pose =  0.000, velocity[z]=-14.482, score =205.922(best =562.607,worst =  6.439)
# Episode = 461,pose =  0.000, velocity[z]=-14.507, score =205.916(best =562.607,worst =  6.439)
# Episode = 462,pose =  0.000, velocity[z]=-14.591, score =205.904(best =562.607,worst =  6.439)
# Episode = 463,pose =  0.000, velocity[z]=-14.471, score =205.919(best =562.607,worst =  6.439)
# Episode = 464,pose =  0.000, velocity[z]=-14.480, score =205.920(best =562.607,worst =  6.439)
# Episode = 465,pose =  0.000, velocity[z]=-14.328, score =195.945(best =562.607,worst =  6.439)
# Episode = 466,pose =  0.000, velocity[z]=-14.462, score =195.925(best =562.607,worst =  6.439)
# Episode = 467,pose =  0.000, velocity[z]=-14.468, score =195.933(best =562.607,worst =  6.439)
# Episode = 468,pose =  0.000, velocity[z]=-16.029, score =222.309(best =562.607,worst =  6.439)
# Episode = 469,pose =  0.000, velocity[z]=-14.594, score =205.908(best =562.607,worst =  6.439)
# Episode = 470,pose =  0.000, velocity[z]=-14.439, score =195.931(best =562.607,worst =  6.439)
# Episode = 471,pose =  0.000, velocity[z]=-14.495, score =205.918(best =562.607,worst =  6.439)
# Episode = 472,pose =  0.000, velocity[z]=-14.488, score =205.922(best =562.607,worst =  6.439)
# Episode = 473,pose =  0.000, velocity[z]=-14.471, score =205.924(best =562.607,worst =  6.439)
# Episode = 474,pose =  0.000, velocity[z]=-14.428, score =195.928(best =562.607,worst =  6.439)
# Episode = 475,pose =  0.000, velocity[z]=-14.660, score =215.897(best =562.607,worst =  6.439)
# Episode = 476,pose =  0.000, velocity[z]=-14.763, score =215.883(best =562.607,worst =  6.439)
# Episode = 477,pose =  0.000, velocity[z]=-14.525, score =205.913(best =562.607,worst =  6.439)
# Episode = 478,pose =  0.000, velocity[z]=-14.352, score =195.940(best =562.607,worst =  6.439)
# Episode = 479,pose =  0.000, velocity[z]=-14.715, score =215.887(best =562.607,worst =  6.439)
# Episode = 480,pose =  0.000, velocity[z]=-14.586, score =205.904(best =562.607,worst =  6.439)
# Episode = 481,pose =  0.000, velocity[z]=-14.579, score =205.907(best =562.607,worst =  6.439)
# Episode = 482,pose =  0.000, velocity[z]=-14.397, score =195.939(best =562.607,worst =  6.439)
# Episode = 483,pose =  0.000, velocity[z]=-14.385, score =195.934(best =562.607,worst =  6.439)
# Episode = 484,pose =  0.000, velocity[z]=-14.568, score =205.904(best =562.607,worst =  6.439)
# Episode = 485,pose =  0.000, velocity[z]=-14.464, score =195.922(best =562.607,worst =  6.439)
# Episode = 486,pose =  0.000, velocity[z]=-14.607, score =205.903(best =562.607,worst =  6.439)
# Episode = 487,pose =  0.000, velocity[z]=-14.433, score =195.923(best =562.607,worst =  6.439)
# Episode = 488,pose =  0.000, velocity[z]=-14.420, score =195.927(best =562.607,worst =  6.439)
# Episode = 489,pose =  0.000, velocity[z]=-14.427, score =195.933(best =562.607,worst =  6.439)
# Episode = 490,pose =  0.000, velocity[z]=-14.607, score =215.899(best =562.607,worst =  6.439)
# Episode = 491,pose =  0.000, velocity[z]=-14.599, score =205.903(best =562.607,worst =  6.439)
# Episode = 492,pose =  0.000, velocity[z]=-14.477, score =205.921(best =562.607,worst =  6.439)
# Episode = 493,pose =  0.000, velocity[z]=-14.483, score =205.922(best =562.607,worst =  6.439)
# Episode = 494,pose =  0.000, velocity[z]=-14.597, score =205.903(best =562.607,worst =  6.439)
# Episode = 495,pose =  0.000, velocity[z]=-14.632, score =215.896(best =562.607,worst =  6.439)
# Episode = 496,pose =  0.000, velocity[z]=-14.650, score =215.893(best =562.607,worst =  6.439)
# Episode = 497,pose =  0.000, velocity[z]=-14.619, score =215.900(best =562.607,worst =  6.439)
# Episode = 498,pose =  0.000, velocity[z]=-14.481, score =205.922(best =562.607,worst =  6.439)
# Episode = 499,pose =  0.000, velocity[z]=-14.586, score =205.908(best =562.607,worst =  6.439)
# Episode = 500,pose =  0.000, velocity[z]=-14.489, score =205.920(best =562.607,worst =  6.439)
# Episode = 501,pose =  0.000, velocity[z]=-14.463, score =195.924(best =562.607,worst =  6.439)
# Episode = 502,pose =  0.000, velocity[z]=-14.444, score =195.926(best =562.607,worst =  6.439)
# Episode = 503,pose =  0.000, velocity[z]=-14.418, score =195.929(best =562.607,worst =  6.439)
# Episode = 504,pose =  0.000, velocity[z]=-14.441, score =195.923(best =562.607,worst =  6.439)
# Episode = 505,pose =  0.000, velocity[z]=-14.537, score =205.911(best =562.607,worst =  6.439)
# Episode = 506,pose =  0.000, velocity[z]=-14.490, score =205.923(best =562.607,worst =  6.439)
# Episode = 507,pose =  0.000, velocity[z]=-14.473, score =205.919(best =562.607,worst =  6.439)
# Episode = 508,pose =  0.000, velocity[z]=-14.580, score =205.906(best =562.607,worst =  6.439)
# Episode = 509,pose =  0.000, velocity[z]=-14.475, score =205.921(best =562.607,worst =  6.439)
# Episode = 510,pose =  0.000, velocity[z]=-14.525, score =205.914(best =562.607,worst =  6.439)
# Episode = 511,pose =  0.000, velocity[z]=-14.426, score =195.928(best =562.607,worst =  6.439)
# Episode = 512,pose =  0.000, velocity[z]=-14.391, score =195.938(best =562.607,worst =  6.439)
# Episode = 513,pose =  0.000, velocity[z]=-14.464, score =205.920(best =562.607,worst =  6.439)
# Episode = 514,pose =  0.000, velocity[z]=-14.477, score =205.916(best =562.607,worst =  6.439)
# Episode = 515,pose =  0.000, velocity[z]=-14.417, score =195.929(best =562.607,worst =  6.439)
# Episode = 516,pose =  0.000, velocity[z]=-14.659, score =215.894(best =562.607,worst =  6.439)
# Episode = 517,pose =  0.000, velocity[z]=-14.505, score =205.919(best =562.607,worst =  6.439)
# Episode = 518,pose =  0.000, velocity[z]=-14.539, score =205.907(best =562.607,worst =  6.439)
# Episode = 519,pose =  0.000, velocity[z]=-14.383, score =195.933(best =562.607,worst =  6.439)
# Episode = 520,pose =  0.000, velocity[z]=-14.516, score =205.917(best =562.607,worst =  6.439)
# Episode = 521,pose =  0.000, velocity[z]=-14.342, score =195.939(best =562.607,worst =  6.439)
# Episode = 522,pose =  0.000, velocity[z]=-14.583, score =205.903(best =562.607,worst =  6.439)
# Episode = 523,pose =  0.000, velocity[z]=-14.382, score =195.936(best =562.607,worst =  6.439)
# Episode = 524,pose =  0.000, velocity[z]=-14.411, score =195.930(best =562.607,worst =  6.439)
# Episode = 525,pose =  0.000, velocity[z]=-14.435, score =195.927(best =562.607,worst =  6.439)
# Episode = 526,pose =  0.000, velocity[z]=-14.714, score =215.887(best =562.607,worst =  6.439)
# Episode = 527,pose =  0.000, velocity[z]=-14.509, score =205.918(best =562.607,worst =  6.439)
# Episode = 528,pose =  0.000, velocity[z]=-14.369, score =195.928(best =562.607,worst =  6.439)
# Episode = 529,pose =  0.000, velocity[z]=-14.480, score =205.920(best =562.607,worst =  6.439)
# Episode = 530,pose =  0.000, velocity[z]=-14.572, score =205.906(best =562.607,worst =  6.439)
# Episode = 531,pose =  0.000, velocity[z]=-14.492, score =205.918(best =562.607,worst =  6.439)
# Episode = 532,pose =  0.000, velocity[z]=-14.575, score =205.909(best =562.607,worst =  6.439)
# Episode = 533,pose =  0.000, velocity[z]=-14.467, score =205.920(best =562.607,worst =  6.439)
# Episode = 534,pose =  0.000, velocity[z]=-14.681, score =215.891(best =562.607,worst =  6.439)
# Episode = 535,pose =  0.000, velocity[z]=-14.429, score =205.910(best =562.607,worst =  6.439)
# Episode = 536,pose =  0.000, velocity[z]=-14.423, score =195.930(best =562.607,worst =  6.439)
# Episode = 537,pose =  0.000, velocity[z]=-14.470, score =205.916(best =562.607,worst =  6.439)
# Episode = 538,pose =  0.000, velocity[z]=-14.431, score =205.921(best =562.607,worst =  6.439)
# Episode = 539,pose =  0.000, velocity[z]=-14.496, score =205.924(best =562.607,worst =  6.439)
# Episode = 540,pose =  0.000, velocity[z]=-16.078, score =222.301(best =562.607,worst =  6.439)
# Episode = 541,pose =  0.000, velocity[z]=-13.545, score =189.526(best =562.607,worst =  6.439)
# Episode = 542,pose =  0.000, velocity[z]=-14.427, score =195.922(best =562.607,worst =  6.439)
# Episode = 543,pose =  0.000, velocity[z]=-14.430, score =195.928(best =562.607,worst =  6.439)
# Episode = 544,pose =  0.000, velocity[z]=-14.479, score =205.920(best =562.607,worst =  6.439)
# Episode = 545,pose =  0.000, velocity[z]=-14.588, score =205.902(best =562.607,worst =  6.439)
# Episode = 546,pose =  0.000, velocity[z]=-14.402, score =195.934(best =562.607,worst =  6.439)
# Episode = 547,pose =  0.000, velocity[z]=-14.504, score =205.919(best =562.607,worst =  6.439)
# Episode = 548,pose =  0.000, velocity[z]=-14.444, score =195.925(best =562.607,worst =  6.439)
# Episode = 549,pose =  0.000, velocity[z]=-14.526, score =205.919(best =562.607,worst =  6.439)
# Episode = 550,pose =  0.000, velocity[z]=-14.421, score =195.931(best =562.607,worst =  6.439)
# Episode = 551,pose =  0.000, velocity[z]=-14.413, score =195.936(best =562.607,worst =  6.439)
# Episode = 552,pose =  0.000, velocity[z]=-14.396, score =195.932(best =562.607,worst =  6.439)
# Episode = 553,pose =  0.000, velocity[z]=-14.513, score =205.916(best =562.607,worst =  6.439)
# Episode = 554,pose =  0.000, velocity[z]=-14.509, score =205.915(best =562.607,worst =  6.439)
# Episode = 555,pose =  0.000, velocity[z]=-14.439, score =195.930(best =562.607,worst =  6.439)
# Episode = 556,pose =  0.000, velocity[z]=-14.549, score =205.911(best =562.607,worst =  6.439)
# Episode = 557,pose =  0.000, velocity[z]=-14.631, score =215.901(best =562.607,worst =  6.439)
# Episode = 558,pose =  0.000, velocity[z]=-14.603, score =205.907(best =562.607,worst =  6.439)
# Episode = 559,pose =  0.000, velocity[z]=-14.446, score =195.927(best =562.607,worst =  6.439)
# Episode = 560,pose =  0.000, velocity[z]=-14.616, score =215.902(best =562.607,worst =  6.439)
# Episode = 561,pose =  0.000, velocity[z]=-14.601, score =205.906(best =562.607,worst =  6.439)
# Episode = 562,pose =  0.000, velocity[z]=-14.571, score =205.905(best =562.607,worst =  6.439)
# Episode = 563,pose =  0.000, velocity[z]=-14.491, score =205.918(best =562.607,worst =  6.439)
# Episode = 564,pose =  0.000, velocity[z]=-14.529, score =205.913(best =562.607,worst =  6.439)
# Episode = 565,pose =  0.000, velocity[z]=-14.725, score =215.884(best =562.607,worst =  6.439)
# Episode = 566,pose =  0.000, velocity[z]=-14.524, score =205.917(best =562.607,worst =  6.439)
# Episode = 567,pose =  0.000, velocity[z]=-14.461, score =195.921(best =562.607,worst =  6.439)
# Episode = 568,pose =  0.000, velocity[z]=-14.578, score =215.888(best =562.607,worst =  6.439)
# Episode = 569,pose =  0.000, velocity[z]=-14.497, score =205.916(best =562.607,worst =  6.439)
# Episode = 570,pose =  0.000, velocity[z]=-14.328, score =195.942(best =562.607,worst =  6.439)
# Episode = 571,pose =  0.000, velocity[z]=-14.319, score =195.949(best =562.607,worst =  6.439)
# Episode = 572,pose =  0.000, velocity[z]=-14.613, score =215.899(best =562.607,worst =  6.439)
# Episode = 573,pose =  0.000, velocity[z]=-14.516, score =205.911(best =562.607,worst =  6.439)
# Episode = 574,pose =  0.000, velocity[z]=-14.333, score =195.943(best =562.607,worst =  6.439)
# Episode = 575,pose =  0.000, velocity[z]=-14.390, score =195.925(best =562.607,worst =  6.439)
# Episode = 576,pose =  0.000, velocity[z]=-15.971, score =222.320(best =562.607,worst =  6.439)
# Episode = 577,pose =  0.000, velocity[z]=-16.057, score =222.308(best =562.607,worst =  6.439)
# Episode = 578,pose =  0.000, velocity[z]=-14.652, score =215.897(best =562.607,worst =  6.439)
# Episode = 579,pose =  0.000, velocity[z]=-14.471, score =205.926(best =562.607,worst =  6.439)
# Episode = 580,pose =  0.000, velocity[z]=-14.394, score =195.936(best =562.607,worst =  6.439)
# Episode = 581,pose =  0.000, velocity[z]=-14.625, score =215.896(best =562.607,worst =  6.439)
# Episode = 582,pose =  0.000, velocity[z]=-14.523, score =205.913(best =562.607,worst =  6.439)
# Episode = 583,pose =  0.000, velocity[z]=-14.583, score =205.898(best =562.607,worst =  6.439)
# Episode = 584,pose =  0.000, velocity[z]=-14.389, score =195.938(best =562.607,worst =  6.439)
# Episode = 585,pose =  0.000, velocity[z]=-14.559, score =205.909(best =562.607,worst =  6.439)
# Episode = 586,pose =  0.000, velocity[z]=-14.453, score =205.923(best =562.607,worst =  6.439)
# Episode = 587,pose =  0.000, velocity[z]=-14.423, score =195.931(best =562.607,worst =  6.439)
# Episode = 588,pose =  0.000, velocity[z]=-14.399, score =195.937(best =562.607,worst =  6.439)
# Episode = 589,pose =  0.000, velocity[z]=-14.587, score =205.909(best =562.607,worst =  6.439)
# Episode = 590,pose =  0.000, velocity[z]=-14.405, score =195.931(best =562.607,worst =  6.439)
# Episode = 591,pose =  0.000, velocity[z]=-14.487, score =205.922(best =562.607,worst =  6.439)
# Episode = 592,pose =  0.000, velocity[z]=-14.590, score =205.914(best =562.607,worst =  6.439)
# Episode = 593,pose =  0.000, velocity[z]=-14.669, score =247.677(best =562.607,worst =  6.439)
# Episode = 594,pose =  0.000, velocity[z]=-16.298, score =203.024(best =562.607,worst =  6.439)
# Episode = 595,pose = 32.604, velocity[z]=  4.970, score =560.518(best =562.607,worst =  6.439)
# Episode = 596,pose = 34.805, velocity[z]=  7.885, score =562.383(best =562.607,worst =  6.439)
# Episode = 597,pose =  0.000, velocity[z]=-17.030, score =546.703(best =562.607,worst =  6.439)
# Episode = 598,pose = 35.587, velocity[z]=  9.342, score =562.468(best =562.607,worst =  6.439)
# Episode = 599,pose = 26.821, velocity[z]= -6.229, score =562.032(best =562.607,worst =  6.439)
# Episode = 600,pose =  0.000, velocity[z]=-15.075, score =254.475(best =562.607,worst =  6.439)

# %%
plot_run(results)

# %%
path = [[results['x'][i], results['y'][i], results['z'][i]] for i in range(len(results['x']))]
show_flight_path(path, target=target_pos)

# %% [markdown]
# ## 绘制阶段奖励
#
# 请绘制智能体在每个阶段中获得的总奖励，这可以是单次运行的奖励值，也可以是多次运行的平均值。

# %%
## TODO: Plot the rewards.
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_rewards(rewards):

    plt.title('rewards')
    plt.xlabel('episode')
    plt.ylabel('rewards')
    
    plt.plot(rewards['episode'], rewards['reward'], label='reward/episode')
    plt.legend()
    _ = plt.ylim()

# %%
plot_rewards(rewards)

# %% [markdown]
# ## 回顾
#
# **问题 1**：请描述你在 `task.py` 中指定的任务。你如何设计奖励函数？
#
# **回答**：
# 在quadcopter_task.py中定义的任务为
# 实际位置与目标位置相差越小，获得的奖励值越大，为了避免奖励函数梯度爆炸造成不稳定，使用tanh把每次的奖励限定在(-1,1)范围内。
# 通过调试， takeoff任务最终确定的奖励函数：reward = np.tanh(1 - 0.003*(abs(self.sim.pose[:3] - self.target_pos))).sum()

# %% [markdown]
# **问题 2**：请简要描述你的智能体，你可以参考以下问题：
#
# - 你尝试了哪些学习算法？哪个效果最好？
# - 你最终选择了哪些超参数（比如 $\alpha$，$\gamma$，$\epsilon$ 等）？
# - 你使用了什么样的神经网络结构（如果有的话）？请说明层数、大小和激活函数等信息。
#
# **回答**：
#
#
# 1.我的学习算法是参考深度确定性策略梯度算法，简称 DDPG。该算法适合与连续状态空间
#
# 2.选择超参数：
# exploration_mu = 0
# exploration_theta = 0.15
# exploration_sigma = 0.2
# self.buffer_size = 100000
# self.batch_size = 64
# gamma = 0.99
# tau = 0.01
#
# 3.所用神经网络结构
# Actor:
#
# Dense(units=100) + BatchNorm + L2 Regularisation + ReLu Activation
# Dense(units=200) + BatchNorm + L2 Regularisation + ReLu Activation
# Dense(units=self.actionsize) + Sigmoid Activation
# Critic:
#
# states part:
# Dense(units=100) + BatchNorm + L2 Regularisation + ReLu Activation
# Dense(units=200) + BatchNorm + L2 Regularisation + ReLu Activation
# action part:
# Dense(units=100) + BatchNorm + L2 Regularisation + ReLu Activation
# Dense(units=200) + BatchNorm + L2 Regularisation + ReLu Activation
# Combining : Add with ReLu Activation

# %% [markdown]
# **问题 3**：根据你绘制的奖励图，描述智能体的学习状况。
#
# - 学习该任务是简单还是困难？
# - 该学习曲线中是否存在循序渐进或急速上升的部分？
# - 该智能体的最终性能有多好？（比如最后十个阶段的平均奖励值）
#
# **回答**：

# %%
print("Final Performance (Mean Reward over last 10 episodes): {}".format(np.sum(rewards['reward'][-10:])/10))
# Out:
# Final Performance (Mean Reward over last 10 episodes): 572.0940016456152

# %% [markdown]
# **问题 4**：请简要总结你的本次项目经历。你可以参考以下问题：
#
# - 本次项目中最困难的部分是什么？（例如开始项目、运行 ROS、绘制、特定的任务等。）
# - 关于四轴飞行器和你的智能体的行为，你是否有一些有趣的发现？
#
# **回答**：
#
# 1.最大的困难在于对连续空间深度学习概念的理解。以及对DDPG算法的理解，参数调试。
#
# 2.获得的奖励小于400，会导致起飞失败

# %% [markdown]
# ### (可选)Plot Actor 及 Critic 结构
# 建议使用 ```from keras.utils import plot_model``` 来显示模型结构；
